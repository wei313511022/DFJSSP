# %% [markdown]
# # DDQN Runner Notebook
#
# This notebook is intentionally thin: keep parameters here, then call `main.py` modules.
# Edit the config cell and run all.

# %%
# %matplotlib qt
import os
import torch
import torch.nn as nn
import torch.optim as optim

from env import TaskSchedulingEnv
from model import QNetwork
from trainer import prepare_scenarios, train_ddqn
from evaluator import run_test_and_plot, print_batch_results

# %%
# -----------------------------
# Parameters (edit this block)
# -----------------------------
CFG = {
    # Data source and generation
    'task_file': 'dispatch_batches.jsonl',
    'train_data_dir': os.path.join(os.getcwd(), 'train_data'),
    'auto_generate_data': False,
    'gen_batches': 1,
    'gen_size': None,
    'gen_min_size': 1,
    'gen_max_size': 25,
    'gen_arrival_mean': 100,
    'gen_seed': None,
    'multi_streams': True,
    'num_streams': 2000,
    'base_seed': 100,
    'stream_file_template': 'dispatch_batches_{i}.jsonl',

    # Scenario sampling
    'sampling_mode': 'full',  # full | window | subset
    'window_size': 10,
    'subset_size': 10,

    # Train/test switches
    'do_train': True,
    'do_test': True,

    # Model checkpoint
    'save_model_path': 'ddqn_policy_static_sch_no_avoidance.pt',
    'load_model_path': None,

    # DDQN and optimizer
    'state_dim': 28,
    'action_dim': 4,
    'lr': 1e-3,
    'num_episodes': 1000,
    'batch_size': 128,
    'gamma': 0.99,
    'epsilon': 1.0,
    'epsilon_end': 0.05,
    'epsilon_decay': 0.995,
    'allow_proactive_replenish': True,
    'enable_collision_avoidance': False,

    # Training visualization and profiling
    'show_train_schedule': True,
    'train_schedule_every_episodes': 1,
    'train_schedule_every_steps': 1,
    'train_schedule_window': 120.0,
    'train_schedule_window_all_axes': False,
    'train_schedule_pause': 0.01,
    'train_schedule_show_labels': False,
    'train_schedule_figsize': (14, 8),
    'show_train_route_map': False,
    'train_route_map_every_episodes': 1,
    'train_route_map_every_steps': 1,
    'train_route_map_pause': 0.01,
    'train_route_map_figsize': (9, 8),
    'train_route_map_animate': False,
    'train_route_map_time_step': 0.5,
    'train_route_map_max_frames_per_update': 1000,
    'train_route_map_delay_seconds': 0,
    'enable_profile': True,
    'profile_cuda_sync': True,

    # Test and plotting
    'test_scenario_file': 'test_scenario_one_time.jsonl',
    'show_live': False,
    'show_live_stream': False,
    'show_interactive': False,
    'show_route_map': True,
    'show_plotly': True,
    'show_test_plots': True,
    'live_pause': 0.05,
    'live_job_file': 'live_jobs.jsonl',
    'live_start_at_end': True,
    'live_poll_interval': 0.5,
    'live_idle_sleep': 0.1,
    'live_max_steps': 100,
    'live_max_sim_time': None,
    'live_init_scenario': [],
    'live_record_dir': None,
    'live_record_every': 5,
    'live_record_dpi': 140,
    'live_make_gif': False,
    'live_gif_path': 'live_schedule.gif',
    'route_play_step': 0.5,
    'route_play_interval_ms': 120,
}

# %%
# -----------------------------
# Run pipeline
# -----------------------------
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

scenario_list = prepare_scenarios(
    task_file=CFG['task_file'],
    train_data_dir=CFG['train_data_dir'],
    auto_generate_data=CFG['auto_generate_data'],
    gen_batches=CFG['gen_batches'],
    gen_size=CFG['gen_size'],
    gen_min_size=CFG['gen_min_size'],
    gen_max_size=CFG['gen_max_size'],
    gen_arrival_mean=CFG['gen_arrival_mean'],
    gen_seed=CFG['gen_seed'],
    multi_streams=CFG['multi_streams'],
    num_streams=CFG['num_streams'],
    base_seed=CFG['base_seed'],
    stream_file_template=CFG['stream_file_template'],
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
if device.type == 'cuda':
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.set_float32_matmul_precision('high')

env = TaskSchedulingEnv()
env.allow_proactive_replenish = CFG['allow_proactive_replenish']
env.enable_collision_avoidance = CFG['enable_collision_avoidance']
input_dim = CFG['state_dim'] + CFG['action_dim']
policy_net = QNetwork(input_dim).to(device)
target_net = QNetwork(input_dim).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=CFG['lr'])
criterion = nn.MSELoss()

if CFG['load_model_path'] and os.path.exists(CFG['load_model_path']):
    ckpt = torch.load(CFG['load_model_path'], map_location=device)
    if isinstance(ckpt, dict) and 'model_state' in ckpt:
        policy_net.load_state_dict(ckpt['model_state'])
        if 'target_state' in ckpt:
            target_net.load_state_dict(ckpt['target_state'])
        else:
            target_net.load_state_dict(policy_net.state_dict())
        if 'optimizer_state' in ckpt:
            optimizer.load_state_dict(ckpt['optimizer_state'])
    else:
        policy_net.load_state_dict(ckpt)
        target_net.load_state_dict(policy_net.state_dict())
    print(f"Loaded model from {CFG['load_model_path']}")

if CFG['do_train']:
    _train_info = train_ddqn(
        env=env,
        policy_net=policy_net,
        target_net=target_net,
        optimizer=optimizer,
        criterion=criterion,
        scenario_list=scenario_list,
        device=device,
        num_episodes=CFG['num_episodes'],
        batch_size=CFG['batch_size'],
        gamma=CFG['gamma'],
        epsilon=CFG['epsilon'],
        epsilon_end=CFG['epsilon_end'],
        epsilon_decay=CFG['epsilon_decay'],
        sampling_mode=CFG['sampling_mode'],
        window_size=CFG['window_size'],
        subset_size=CFG['subset_size'],
        show_train_schedule=CFG['show_train_schedule'],
        train_schedule_every_episodes=CFG['train_schedule_every_episodes'],
        train_schedule_every_steps=CFG['train_schedule_every_steps'],
        train_schedule_window=CFG['train_schedule_window'],
        train_schedule_window_all_axes=CFG['train_schedule_window_all_axes'],
        train_schedule_pause=CFG['train_schedule_pause'],
        train_schedule_show_labels=CFG['train_schedule_show_labels'],
        train_schedule_figsize=CFG['train_schedule_figsize'],
        show_train_route_map=CFG['show_train_route_map'],
        train_route_map_every_episodes=CFG['train_route_map_every_episodes'],
        train_route_map_every_steps=CFG['train_route_map_every_steps'],
        train_route_map_pause=CFG['train_route_map_pause'],
        train_route_map_figsize=CFG['train_route_map_figsize'],
        train_route_map_animate=CFG['train_route_map_animate'],
        train_route_map_time_step=CFG['train_route_map_time_step'],
        train_route_map_max_frames_per_update=CFG['train_route_map_max_frames_per_update'],
        train_route_map_delay_seconds=CFG['train_route_map_delay_seconds'],
        enable_profile=CFG['enable_profile'],
        profile_cuda_sync=CFG['profile_cuda_sync'],
    )

    if CFG['save_model_path']:
        ckpt = {
            'model_state': policy_net.state_dict(),
            'target_state': target_net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'state_dim': CFG['state_dim'],
            'action_dim': CFG['action_dim'],
            'input_dim': input_dim,
        }
        torch.save(ckpt, CFG['save_model_path'])
        print(f"Saved model to {CFG['save_model_path']}")

if CFG['do_test']:
    _mk = run_test_and_plot(
        env=env,
        policy_net=policy_net,
        device=device,
        scenario_list=scenario_list,
        test_scenario_file=CFG['test_scenario_file'],
        show_live=CFG['show_live'],
        show_live_stream=CFG['show_live_stream'],
        show_interactive=CFG['show_interactive'],
        show_route_map=CFG['show_route_map'],
        show_plotly=CFG['show_plotly'],
        show_test_plots=CFG['show_test_plots'],
        live_pause=CFG['live_pause'],
        live_job_file=CFG['live_job_file'],
        live_start_at_end=CFG['live_start_at_end'],
        live_poll_interval=CFG['live_poll_interval'],
        live_idle_sleep=CFG['live_idle_sleep'],
        live_max_steps=CFG['live_max_steps'],
        live_max_sim_time=CFG['live_max_sim_time'],
        live_init_scenario=CFG['live_init_scenario'],
        live_record_dir=CFG['live_record_dir'],
        live_record_every=CFG['live_record_every'],
        live_record_dpi=CFG['live_record_dpi'],
        live_make_gif=CFG['live_make_gif'],
        live_gif_path=CFG['live_gif_path'],
        route_play_step=CFG['route_play_step'],
        route_play_interval_ms=CFG['route_play_interval_ms'],
    )
    print_batch_results(env=env, policy_net=policy_net, device=device, scenario_list=scenario_list)
# Out:
# device = cuda
# [EP 1] batch=stream:1 dispatch_time=54.30 release_t0=0.00 jobs=6 MA-50 mk: 94.00, mk/job: 15.667, mk/proc: 0.895, eps=0.995, last_mk=94.00
# [EP 2] batch=stream:1 dispatch_time=176.10 release_t0=0.00 jobs=1 MA-50 mk: 62.50, mk/job: 31.000, mk/proc: 2.067, eps=0.990, last_mk=31.00
# [EP 3] batch=stream:1 dispatch_time=54.87 release_t0=0.00 jobs=18 MA-50 mk: 114.67, mk/job: 12.167, mk/proc: 0.826, eps=0.985, last_mk=219.00
# [EP 4] batch=stream:1 dispatch_time=201.78 release_t0=0.00 jobs=23 MA-50 mk: 161.25, mk/job: 13.087, mk/proc: 0.848, eps=0.980, last_mk=301.00
# [EP 5] batch=stream:1 dispatch_time=7.55 release_t0=0.00 jobs=24 MA-50 mk: 183.80, mk/job: 11.417, mk/proc: 0.772, eps=0.975, last_mk=274.00
# [EP 6] batch=stream:1 dispatch_time=76.09 release_t0=0.00 jobs=17 MA-50 mk: 188.50, mk/job: 12.471, mk/proc: 0.902, eps=0.970, last_mk=212.00
# [EP 7] batch=stream:1 dispatch_time=72.59 release_t0=0.00 jobs=15 MA-50 mk: 190.71, mk/job: 13.600, mk/proc: 0.868, eps=0.966, last_mk=204.00
# [EP 8] batch=stream:1 dispatch_time=15.35 release_t0=0.00 jobs=5 MA-50 mk: 177.50, mk/job: 17.000, mk/proc: 1.214, eps=0.961, last_mk=85.00
# [EP 9] batch=stream:1 dispatch_time=293.79 release_t0=0.00 jobs=22 MA-50 mk: 188.56, mk/job: 12.591, mk/proc: 0.815, eps=0.956, last_mk=277.00
# [EP 10] batch=stream:1 dispatch_time=26.11 release_t0=0.00 jobs=23 MA-50 mk: 200.70, mk/job: 13.478, mk/proc: 0.838, eps=0.951, last_mk=310.00
# [EP 11] batch=stream:1 dispatch_time=46.97 release_t0=0.00 jobs=9 MA-50 mk: 193.18, mk/job: 13.111, mk/proc: 0.874, eps=0.946, last_mk=118.00
# [EP 12] batch=stream:1 dispatch_time=2.66 release_t0=0.00 jobs=6 MA-50 mk: 184.08, mk/job: 14.000, mk/proc: 0.884, eps=0.942, last_mk=84.00
# [EP 13] batch=stream:1 dispatch_time=106.72 release_t0=0.00 jobs=20 MA-50 mk: 189.00, mk/job: 12.400, mk/proc: 0.841, eps=0.937, last_mk=248.00
# [EP 14] batch=stream:1 dispatch_time=183.14 release_t0=0.00 jobs=16 MA-50 mk: 190.71, mk/job: 13.312, mk/proc: 0.968, eps=0.932, last_mk=213.00
# [EP 15] batch=stream:1 dispatch_time=124.53 release_t0=0.00 jobs=10 MA-50 mk: 186.73, mk/job: 13.100, mk/proc: 0.845, eps=0.928, last_mk=131.00
# [EP 16] batch=stream:1 dispatch_time=10.15 release_t0=0.00 jobs=20 MA-50 mk: 191.75, mk/job: 13.350, mk/proc: 0.861, eps=0.923, last_mk=267.00
# [EP 17] batch=stream:1 dispatch_time=104.15 release_t0=0.00 jobs=3 MA-50 mk: 183.47, mk/job: 17.000, mk/proc: 1.020, eps=0.918, last_mk=51.00
# [EP 18] batch=stream:1 dispatch_time=44.20 release_t0=0.00 jobs=9 MA-50 mk: 180.56, mk/job: 14.556, mk/proc: 0.936, eps=0.914, last_mk=131.00
# [EP 19] batch=stream:1 dispatch_time=80.03 release_t0=0.00 jobs=8 MA-50 mk: 177.21, mk/job: 14.625, mk/proc: 0.975, eps=0.909, last_mk=117.00
# [EP 20] batch=stream:1 dispatch_time=73.16 release_t0=0.00 jobs=17 MA-50 mk: 178.70, mk/job: 12.176, mk/proc: 0.900, eps=0.905, last_mk=207.00
# [EP 21] batch=stream:1 dispatch_time=81.43 release_t0=0.00 jobs=1 MA-50 mk: 171.81, mk/job: 34.000, mk/proc: 3.400, eps=0.900, last_mk=34.00
# [EP 22] batch=stream:1 dispatch_time=103.80 release_t0=0.00 jobs=6 MA-50 mk: 167.64, mk/job: 13.333, mk/proc: 0.889, eps=0.896, last_mk=80.00
# [EP 23] batch=stream:1 dispatch_time=8.25 release_t0=0.00 jobs=11 MA-50 mk: 166.48, mk/job: 12.818, mk/proc: 0.855, eps=0.891, last_mk=141.00
# [EP 24] batch=stream:1 dispatch_time=26.14 release_t0=0.00 jobs=11 MA-50 mk: 165.33, mk/job: 12.636, mk/proc: 0.794, eps=0.887, last_mk=139.00
# [EP 25] batch=stream:1 dispatch_time=192.71 release_t0=0.00 jobs=18 MA-50 mk: 167.44, mk/job: 12.111, mk/proc: 0.908, eps=0.882, last_mk=218.00
# [EP 26] batch=stream:1 dispatch_time=97.89 release_t0=0.00 jobs=24 MA-50 mk: 172.73, mk/job: 12.708, mk/proc: 0.847, eps=0.878, last_mk=305.00
# [EP 27] batch=stream:1 dispatch_time=15.91 release_t0=0.00 jobs=10 MA-50 mk: 170.96, mk/job: 12.500, mk/proc: 1.000, eps=0.873, last_mk=125.00
# [EP 28] batch=stream:1 dispatch_time=31.54 release_t0=0.00 jobs=24 MA-50 mk: 175.11, mk/job: 11.958, mk/proc: 0.832, eps=0.869, last_mk=287.00
# [EP 29] batch=stream:1 dispatch_time=4.16 release_t0=0.00 jobs=13 MA-50 mk: 174.97, mk/job: 13.154, mk/proc: 0.924, eps=0.865, last_mk=171.00
# [EP 30] batch=stream:1 dispatch_time=107.84 release_t0=0.00 jobs=13 MA-50 mk: 175.00, mk/job: 13.538, mk/proc: 0.782, eps=0.860, last_mk=176.00
# [EP 31] batch=stream:1 dispatch_time=26.22 release_t0=0.00 jobs=6 MA-50 mk: 172.35, mk/job: 15.500, mk/proc: 0.979, eps=0.856, last_mk=93.00
# [EP 32] batch=stream:1 dispatch_time=66.61 release_t0=0.00 jobs=1 MA-50 mk: 167.97, mk/job: 32.000, mk/proc: 3.200, eps=0.852, last_mk=32.00
# [EP 33] batch=stream:1 dispatch_time=204.05 release_t0=0.00 jobs=4 MA-50 mk: 164.70, mk/job: 15.000, mk/proc: 1.200, eps=0.848, last_mk=60.00
# [EP 34] batch=stream:1 dispatch_time=85.07 release_t0=0.00 jobs=13 MA-50 mk: 164.56, mk/job: 12.308, mk/proc: 0.889, eps=0.843, last_mk=160.00
# [EP 35] batch=stream:1 dispatch_time=115.38 release_t0=0.00 jobs=7 MA-50 mk: 162.91, mk/job: 15.286, mk/proc: 0.793, eps=0.839, last_mk=107.00
# [EP 36] batch=stream:1 dispatch_time=86.97 release_t0=0.00 jobs=4 MA-50 mk: 160.17, mk/job: 16.000, mk/proc: 1.280, eps=0.835, last_mk=64.00
# [EP 37] batch=stream:1 dispatch_time=157.43 release_t0=0.00 jobs=25 MA-50 mk: 164.19, mk/job: 12.360, mk/proc: 0.835, eps=0.831, last_mk=309.00
# [EP 38] batch=stream:1 dispatch_time=75.85 release_t0=0.00 jobs=15 MA-50 mk: 164.79, mk/job: 12.467, mk/proc: 0.796, eps=0.827, last_mk=187.00
# [EP 39] batch=stream:1 dispatch_time=53.63 release_t0=0.00 jobs=10 MA-50 mk: 164.51, mk/job: 15.400, mk/proc: 0.963, eps=0.822, last_mk=154.00
# [EP 40] batch=stream:1 dispatch_time=21.67 release_t0=0.00 jobs=23 MA-50 mk: 168.03, mk/job: 13.261, mk/proc: 0.813, eps=0.818, last_mk=305.00
# [EP 41] batch=stream:1 dispatch_time=18.85 release_t0=0.00 jobs=3 MA-50 mk: 164.95, mk/job: 14.000, mk/proc: 1.050, eps=0.814, last_mk=42.00
# [EP 42] batch=stream:1 dispatch_time=5.97 release_t0=0.00 jobs=24 MA-50 mk: 168.88, mk/job: 13.750, mk/proc: 0.857, eps=0.810, last_mk=330.00
# [EP 43] batch=stream:1 dispatch_time=51.30 release_t0=0.00 jobs=11 MA-50 mk: 168.81, mk/job: 15.091, mk/proc: 1.071, eps=0.806, last_mk=166.00
# [EP 44] batch=stream:1 dispatch_time=402.14 release_t0=0.00 jobs=3 MA-50 mk: 166.09, mk/job: 16.333, mk/proc: 0.891, eps=0.802, last_mk=49.00
# [EP 45] batch=stream:1 dispatch_time=111.17 release_t0=0.00 jobs=8 MA-50 mk: 164.98, mk/job: 14.500, mk/proc: 0.928, eps=0.798, last_mk=116.00
# [EP 46] batch=stream:1 dispatch_time=124.53 release_t0=0.00 jobs=10 MA-50 mk: 164.39, mk/job: 13.800, mk/proc: 0.890, eps=0.794, last_mk=138.00
# [EP 47] batch=stream:1 dispatch_time=79.55 release_t0=0.00 jobs=18 MA-50 mk: 165.91, mk/job: 13.111, mk/proc: 0.858, eps=0.790, last_mk=236.00
# [EP 48] batch=stream:1 dispatch_time=114.38 release_t0=0.00 jobs=7 MA-50 mk: 164.40, mk/job: 13.286, mk/proc: 0.886, eps=0.786, last_mk=93.00
# [EP 49] batch=stream:1 dispatch_time=49.53 release_t0=0.00 jobs=3 MA-50 mk: 162.22, mk/job: 19.333, mk/proc: 1.160, eps=0.782, last_mk=58.00
# [EP 50] batch=stream:1 dispatch_time=18.01 release_t0=0.00 jobs=19 MA-50 mk: 162.78, mk/job: 10.000, mk/proc: 0.704, eps=0.778, last_mk=190.00
# [EP 51] batch=stream:1 dispatch_time=18.69 release_t0=0.00 jobs=6 MA-50 mk: 162.56, mk/job: 13.833, mk/proc: 0.976, eps=0.774, last_mk=83.00
# [EP 52] batch=stream:1 dispatch_time=106.72 release_t0=0.00 jobs=20 MA-50 mk: 167.18, mk/job: 13.100, mk/proc: 0.888, eps=0.771, last_mk=262.00
# [EP 53] batch=stream:1 dispatch_time=246.33 release_t0=0.00 jobs=20 MA-50 mk: 168.06, mk/job: 13.150, mk/proc: 0.892, eps=0.767, last_mk=263.00
# [EP 54] batch=stream:1 dispatch_time=67.69 release_t0=0.00 jobs=11 MA-50 mk: 165.14, mk/job: 14.091, mk/proc: 0.912, eps=0.763, last_mk=155.00
# [EP 55] batch=stream:1 dispatch_time=265.66 release_t0=0.00 jobs=6 MA-50 mk: 161.74, mk/job: 17.333, mk/proc: 1.156, eps=0.759, last_mk=104.00
# [EP 56] batch=stream:1 dispatch_time=52.84 release_t0=0.00 jobs=2 MA-50 mk: 158.10, mk/job: 15.000, mk/proc: 1.200, eps=0.755, last_mk=30.00
# [EP 57] batch=stream:1 dispatch_time=31.50 release_t0=0.00 jobs=20 MA-50 mk: 158.54, mk/job: 11.300, mk/proc: 0.741, eps=0.751, last_mk=226.00
# [EP 58] batch=stream:1 dispatch_time=252.35 release_t0=0.00 jobs=10 MA-50 mk: 159.30, mk/job: 12.300, mk/proc: 0.911, eps=0.748, last_mk=123.00
# [EP 59] batch=stream:1 dispatch_time=182.28 release_t0=0.00 jobs=4 MA-50 mk: 155.28, mk/job: 19.000, mk/proc: 1.169, eps=0.744, last_mk=76.00
# [EP 60] batch=stream:1 dispatch_time=47.61 release_t0=0.00 jobs=9 MA-50 mk: 151.00, mk/job: 10.667, mk/proc: 0.800, eps=0.740, last_mk=96.00
# [EP 61] batch=stream:1 dispatch_time=1.24 release_t0=0.00 jobs=14 MA-50 mk: 151.98, mk/job: 11.929, mk/proc: 0.815, eps=0.737, last_mk=167.00
# [EP 62] batch=stream:1 dispatch_time=205.70 release_t0=0.00 jobs=25 MA-50 mk: 156.16, mk/job: 11.720, mk/proc: 0.792, eps=0.733, last_mk=293.00
# [EP 63] batch=stream:1 dispatch_time=380.11 release_t0=0.00 jobs=13 MA-50 mk: 154.98, mk/job: 14.538, mk/proc: 0.969, eps=0.729, last_mk=189.00
# [EP 64] batch=stream:1 dispatch_time=177.95 release_t0=0.00 jobs=16 MA-50 mk: 154.48, mk/job: 11.750, mk/proc: 0.817, eps=0.726, last_mk=188.00
# [EP 65] batch=stream:1 dispatch_time=133.91 release_t0=0.00 jobs=15 MA-50 mk: 155.76, mk/job: 13.000, mk/proc: 0.951, eps=0.722, last_mk=195.00
# [EP 66] batch=stream:1 dispatch_time=158.24 release_t0=0.00 jobs=16 MA-50 mk: 154.60, mk/job: 13.062, mk/proc: 0.820, eps=0.718, last_mk=209.00
# [EP 67] batch=stream:1 dispatch_time=51.21 release_t0=0.00 jobs=15 MA-50 mk: 157.02, mk/job: 11.467, mk/proc: 0.764, eps=0.715, last_mk=172.00
# [EP 68] batch=stream:1 dispatch_time=72.84 release_t0=0.00 jobs=1 MA-50 mk: 155.08, mk/job: 34.000, mk/proc: 1.700, eps=0.711, last_mk=34.00
# [EP 69] batch=stream:1 dispatch_time=259.80 release_t0=0.00 jobs=16 MA-50 mk: 156.86, mk/job: 12.875, mk/proc: 0.858, eps=0.708, last_mk=206.00
# [EP 70] batch=stream:1 dispatch_time=176.92 release_t0=0.00 jobs=17 MA-50 mk: 157.42, mk/job: 13.824, mk/proc: 0.839, eps=0.704, last_mk=235.00
# [EP 71] batch=stream:1 dispatch_time=259.80 release_t0=0.00 jobs=16 MA-50 mk: 160.68, mk/job: 12.312, mk/proc: 0.821, eps=0.701, last_mk=197.00
# [EP 72] batch=stream:1 dispatch_time=40.67 release_t0=0.00 jobs=16 MA-50 mk: 163.16, mk/job: 12.750, mk/proc: 0.868, eps=0.697, last_mk=204.00
# [EP 73] batch=stream:1 dispatch_time=24.99 release_t0=0.00 jobs=14 MA-50 mk: 163.66, mk/job: 11.857, mk/proc: 0.830, eps=0.694, last_mk=166.00
# [EP 74] batch=stream:1 dispatch_time=72.62 release_t0=0.00 jobs=11 MA-50 mk: 163.90, mk/job: 13.727, mk/proc: 0.944, eps=0.690, last_mk=151.00
# [EP 75] batch=stream:1 dispatch_time=9.15 release_t0=0.00 jobs=13 MA-50 mk: 162.42, mk/job: 11.077, mk/proc: 0.823, eps=0.687, last_mk=144.00
# [EP 76] batch=stream:1 dispatch_time=174.82 release_t0=0.00 jobs=18 MA-50 mk: 161.06, mk/job: 13.167, mk/proc: 0.832, eps=0.683, last_mk=237.00
# [EP 77] batch=stream:1 dispatch_time=43.58 release_t0=0.00 jobs=22 MA-50 mk: 163.62, mk/job: 11.500, mk/proc: 0.755, eps=0.680, last_mk=253.00
# [EP 78] batch=stream:1 dispatch_time=34.46 release_t0=0.00 jobs=16 MA-50 mk: 161.92, mk/job: 12.625, mk/proc: 0.842, eps=0.676, last_mk=202.00
# [EP 79] batch=stream:1 dispatch_time=49.15 release_t0=0.00 jobs=5 MA-50 mk: 160.00, mk/job: 15.000, mk/proc: 1.071, eps=0.673, last_mk=75.00
# [EP 80] batch=stream:1 dispatch_time=11.99 release_t0=0.00 jobs=9 MA-50 mk: 158.66, mk/job: 12.111, mk/proc: 0.991, eps=0.670, last_mk=109.00
# [EP 81] batch=stream:1 dispatch_time=41.24 release_t0=0.00 jobs=25 MA-50 mk: 162.84, mk/job: 12.080, mk/proc: 0.863, eps=0.666, last_mk=302.00
# [EP 82] batch=stream:1 dispatch_time=18.75 release_t0=0.00 jobs=12 MA-50 mk: 165.18, mk/job: 12.417, mk/proc: 0.805, eps=0.663, last_mk=149.00
# [EP 83] batch=stream:1 dispatch_time=102.00 release_t0=0.00 jobs=21 MA-50 mk: 168.92, mk/job: 11.762, mk/proc: 0.810, eps=0.660, last_mk=247.00
# [EP 84] batch=stream:1 dispatch_time=53.63 release_t0=0.00 jobs=10 MA-50 mk: 168.94, mk/job: 16.100, mk/proc: 1.006, eps=0.656, last_mk=161.00
# [EP 85] batch=stream:1 dispatch_time=343.14 release_t0=0.00 jobs=25 MA-50 mk: 172.48, mk/job: 11.360, mk/proc: 0.747, eps=0.653, last_mk=284.00
# [EP 86] batch=stream:1 dispatch_time=9.03 release_t0=0.00 jobs=12 MA-50 mk: 174.62, mk/job: 14.250, mk/proc: 0.834, eps=0.650, last_mk=171.00
# [EP 87] batch=stream:1 dispatch_time=173.50 release_t0=0.00 jobs=25 MA-50 mk: 174.20, mk/job: 11.520, mk/proc: 0.729, eps=0.647, last_mk=288.00
# [EP 88] batch=stream:1 dispatch_time=48.17 release_t0=0.00 jobs=1 MA-50 mk: 171.22, mk/job: 38.000, mk/proc: 1.900, eps=0.643, last_mk=38.00
# [EP 89] batch=stream:1 dispatch_time=12.48 release_t0=0.00 jobs=11 MA-50 mk: 170.98, mk/job: 12.909, mk/proc: 0.835, eps=0.640, last_mk=142.00
# [EP 90] batch=stream:1 dispatch_time=65.37 release_t0=0.00 jobs=20 MA-50 mk: 169.64, mk/job: 11.900, mk/proc: 0.865, eps=0.637, last_mk=238.00
# [EP 91] batch=stream:1 dispatch_time=252.43 release_t0=0.00 jobs=13 MA-50 mk: 172.58, mk/job: 14.538, mk/proc: 0.840, eps=0.634, last_mk=189.00
# [EP 92] batch=stream:1 dispatch_time=441.89 release_t0=0.00 jobs=5 MA-50 mk: 167.62, mk/job: 16.400, mk/proc: 1.262, eps=0.631, last_mk=82.00
# [EP 93] batch=stream:1 dispatch_time=65.81 release_t0=0.00 jobs=20 MA-50 mk: 168.96, mk/job: 11.650, mk/proc: 0.777, eps=0.627, last_mk=233.00
# [EP 94] batch=stream:1 dispatch_time=65.67 release_t0=0.00 jobs=17 MA-50 mk: 172.02, mk/job: 11.882, mk/proc: 0.792, eps=0.624, last_mk=202.00
# [EP 95] batch=stream:1 dispatch_time=165.87 release_t0=0.00 jobs=13 MA-50 mk: 173.48, mk/job: 14.538, mk/proc: 0.995, eps=0.621, last_mk=189.00
# [EP 96] batch=stream:1 dispatch_time=58.69 release_t0=0.00 jobs=2 MA-50 mk: 171.84, mk/job: 28.000, mk/proc: 1.400, eps=0.618, last_mk=56.00
# [EP 97] batch=stream:1 dispatch_time=51.72 release_t0=0.00 jobs=10 MA-50 mk: 170.24, mk/job: 15.600, mk/proc: 0.945, eps=0.615, last_mk=156.00
# [EP 98] batch=stream:1 dispatch_time=122.61 release_t0=0.00 jobs=23 MA-50 mk: 173.48, mk/job: 11.087, mk/proc: 0.729, eps=0.612, last_mk=255.00
# [EP 99] batch=stream:1 dispatch_time=5.18 release_t0=0.00 jobs=21 MA-50 mk: 177.02, mk/job: 11.190, mk/proc: 0.783, eps=0.609, last_mk=235.00
# [EP 100] batch=stream:1 dispatch_time=7.54 release_t0=0.00 jobs=17 MA-50 mk: 176.88, mk/job: 10.765, mk/proc: 0.718, eps=0.606, last_mk=183.00
# [EP 101] batch=stream:1 dispatch_time=78.90 release_t0=0.00 jobs=10 MA-50 mk: 178.04, mk/job: 14.100, mk/proc: 0.972, eps=0.603, last_mk=141.00
# [EP 102] batch=stream:1 dispatch_time=120.14 release_t0=0.00 jobs=1 MA-50 mk: 173.42, mk/job: 31.000, mk/proc: 2.067, eps=0.600, last_mk=31.00
# [EP 103] batch=stream:1 dispatch_time=156.93 release_t0=0.00 jobs=18 MA-50 mk: 173.32, mk/job: 14.333, mk/proc: 0.921, eps=0.597, last_mk=258.00
# [EP 104] batch=stream:1 dispatch_time=106.50 release_t0=0.00 jobs=4 MA-50 mk: 171.48, mk/job: 15.750, mk/proc: 1.145, eps=0.594, last_mk=63.00
# [EP 105] batch=stream:1 dispatch_time=65.81 release_t0=0.00 jobs=20 MA-50 mk: 173.92, mk/job: 11.300, mk/proc: 0.753, eps=0.591, last_mk=226.00
# [EP 106] batch=stream:1 dispatch_time=250.94 release_t0=0.00 jobs=15 MA-50 mk: 177.04, mk/job: 12.400, mk/proc: 0.744, eps=0.588, last_mk=186.00
# [EP 107] batch=stream:1 dispatch_time=33.05 release_t0=0.00 jobs=9 MA-50 mk: 175.16, mk/job: 14.667, mk/proc: 0.978, eps=0.585, last_mk=132.00
# [EP 108] batch=stream:1 dispatch_time=57.33 release_t0=0.00 jobs=7 MA-50 mk: 174.74, mk/job: 14.571, mk/proc: 0.971, eps=0.582, last_mk=102.00
# [EP 109] batch=stream:1 dispatch_time=12.48 release_t0=0.00 jobs=11 MA-50 mk: 176.12, mk/job: 13.182, mk/proc: 0.853, eps=0.579, last_mk=145.00
# [EP 110] batch=stream:1 dispatch_time=3.22 release_t0=0.00 jobs=24 MA-50 mk: 180.22, mk/job: 12.542, mk/proc: 0.782, eps=0.576, last_mk=301.00
# [EP 111] batch=stream:1 dispatch_time=93.44 release_t0=0.00 jobs=21 MA-50 mk: 181.84, mk/job: 11.810, mk/proc: 0.763, eps=0.573, last_mk=248.00
# [EP 112] batch=stream:1 dispatch_time=118.19 release_t0=0.00 jobs=15 MA-50 mk: 179.60, mk/job: 12.067, mk/proc: 0.905, eps=0.570, last_mk=181.00
# [EP 113] batch=stream:1 dispatch_time=54.65 release_t0=0.00 jobs=14 MA-50 mk: 178.94, mk/job: 11.143, mk/proc: 0.867, eps=0.568, last_mk=156.00
# [EP 114] batch=stream:1 dispatch_time=12.68 release_t0=0.00 jobs=17 MA-50 mk: 179.42, mk/job: 12.471, mk/proc: 0.800, eps=0.565, last_mk=212.00
# [EP 115] batch=stream:1 dispatch_time=197.81 release_t0=0.00 jobs=2 MA-50 mk: 176.28, mk/job: 19.000, mk/proc: 1.267, eps=0.562, last_mk=38.00
# [EP 116] batch=stream:1 dispatch_time=22.49 release_t0=0.00 jobs=24 MA-50 mk: 177.10, mk/job: 10.417, mk/proc: 0.794, eps=0.559, last_mk=250.00
# [EP 117] batch=stream:1 dispatch_time=59.86 release_t0=0.00 jobs=17 MA-50 mk: 177.58, mk/job: 11.529, mk/proc: 0.784, eps=0.556, last_mk=196.00
# [EP 118] batch=stream:1 dispatch_time=144.73 release_t0=0.00 jobs=8 MA-50 mk: 179.28, mk/job: 14.875, mk/proc: 1.253, eps=0.554, last_mk=119.00
# [EP 119] batch=stream:1 dispatch_time=102.74 release_t0=0.00 jobs=25 MA-50 mk: 181.20, mk/job: 12.080, mk/proc: 0.774, eps=0.551, last_mk=302.00
# [EP 120] batch=stream:1 dispatch_time=12.76 release_t0=0.00 jobs=3 MA-50 mk: 177.34, mk/job: 14.000, mk/proc: 0.840, eps=0.548, last_mk=42.00
# [EP 121] batch=stream:1 dispatch_time=642.34 release_t0=0.00 jobs=4 MA-50 mk: 174.64, mk/job: 15.500, mk/proc: 1.033, eps=0.545, last_mk=62.00
# [EP 122] batch=stream:1 dispatch_time=24.56 release_t0=0.00 jobs=19 MA-50 mk: 175.60, mk/job: 13.263, mk/proc: 0.826, eps=0.543, last_mk=252.00
# [EP 123] batch=stream:1 dispatch_time=37.89 release_t0=0.00 jobs=13 MA-50 mk: 175.36, mk/job: 11.846, mk/proc: 0.880, eps=0.540, last_mk=154.00
# [EP 124] batch=stream:1 dispatch_time=87.57 release_t0=0.00 jobs=22 MA-50 mk: 177.24, mk/job: 11.136, mk/proc: 0.731, eps=0.537, last_mk=245.00
# [EP 125] batch=stream:1 dispatch_time=243.66 release_t0=0.00 jobs=19 MA-50 mk: 179.12, mk/job: 12.526, mk/proc: 0.850, eps=0.534, last_mk=238.00
# [EP 126] batch=stream:1 dispatch_time=58.97 release_t0=0.00 jobs=21 MA-50 mk: 179.82, mk/job: 12.952, mk/proc: 0.837, eps=0.532, last_mk=272.00
# [EP 127] batch=stream:1 dispatch_time=65.53 release_t0=0.00 jobs=9 MA-50 mk: 177.38, mk/job: 14.556, mk/proc: 1.008, eps=0.529, last_mk=131.00
# [EP 128] batch=stream:1 dispatch_time=15.61 release_t0=0.00 jobs=12 MA-50 mk: 176.60, mk/job: 13.583, mk/proc: 0.906, eps=0.526, last_mk=163.00
# [EP 129] batch=stream:1 dispatch_time=0.80 release_t0=0.00 jobs=24 MA-50 mk: 180.98, mk/job: 12.250, mk/proc: 0.817, eps=0.524, last_mk=294.00
# [EP 130] batch=stream:1 dispatch_time=629.41 release_t0=0.00 jobs=3 MA-50 mk: 179.60, mk/job: 13.333, mk/proc: 1.000, eps=0.521, last_mk=40.00
# [EP 131] batch=stream:1 dispatch_time=131.43 release_t0=0.00 jobs=18 MA-50 mk: 178.02, mk/job: 12.389, mk/proc: 0.756, eps=0.519, last_mk=223.00
# [EP 132] batch=stream:1 dispatch_time=1.43 release_t0=0.00 jobs=13 MA-50 mk: 178.08, mk/job: 11.692, mk/proc: 0.741, eps=0.516, last_mk=152.00
# [EP 133] batch=stream:1 dispatch_time=26.30 release_t0=0.00 jobs=5 MA-50 mk: 174.72, mk/job: 15.800, mk/proc: 0.929, eps=0.513, last_mk=79.00
# [EP 134] batch=stream:1 dispatch_time=642.19 release_t0=0.00 jobs=22 MA-50 mk: 176.70, mk/job: 11.818, mk/proc: 0.722, eps=0.511, last_mk=260.00
# [EP 135] batch=stream:1 dispatch_time=3.59 release_t0=0.00 jobs=23 MA-50 mk: 176.72, mk/job: 12.391, mk/proc: 0.781, eps=0.508, last_mk=285.00
# [EP 136] batch=stream:1 dispatch_time=31.19 release_t0=0.00 jobs=6 MA-50 mk: 175.08, mk/job: 14.833, mk/proc: 1.047, eps=0.506, last_mk=89.00
# [EP 137] batch=stream:1 dispatch_time=87.11 release_t0=0.00 jobs=9 MA-50 mk: 172.00, mk/job: 14.889, mk/proc: 0.957, eps=0.503, last_mk=134.00
# [EP 138] batch=stream:1 dispatch_time=52.07 release_t0=0.00 jobs=3 MA-50 mk: 172.00, mk/job: 12.667, mk/proc: 1.086, eps=0.501, last_mk=38.00
# [EP 139] batch=stream:1 dispatch_time=141.32 release_t0=0.00 jobs=1 MA-50 mk: 169.84, mk/job: 34.000, mk/proc: 1.700, eps=0.498, last_mk=34.00
# [EP 140] batch=stream:1 dispatch_time=7.63 release_t0=0.00 jobs=16 MA-50 mk: 169.12, mk/job: 12.625, mk/proc: 0.878, eps=0.496, last_mk=202.00
# [EP 141] batch=stream:1 dispatch_time=26.05 release_t0=0.00 jobs=15 MA-50 mk: 169.14, mk/job: 12.667, mk/proc: 0.760, eps=0.493, last_mk=190.00
# [EP 142] batch=stream:1 dispatch_time=5.55 release_t0=0.00 jobs=16 MA-50 mk: 171.46, mk/job: 12.375, mk/proc: 0.843, eps=0.491, last_mk=198.00
# [EP 143] batch=stream:1 dispatch_time=231.17 release_t0=0.00 jobs=5 MA-50 mk: 168.18, mk/job: 13.800, mk/proc: 1.062, eps=0.488, last_mk=69.00
# [EP 144] batch=stream:1 dispatch_time=50.57 release_t0=0.00 jobs=3 MA-50 mk: 164.92, mk/job: 13.000, mk/proc: 0.867, eps=0.486, last_mk=39.00
# [EP 145] batch=stream:1 dispatch_time=125.65 release_t0=0.00 jobs=23 MA-50 mk: 166.78, mk/job: 12.261, mk/proc: 0.829, eps=0.483, last_mk=282.00
# [EP 146] batch=stream:1 dispatch_time=140.17 release_t0=0.00 jobs=4 MA-50 mk: 166.86, mk/job: 15.000, mk/proc: 1.091, eps=0.481, last_mk=60.00
# [EP 147] batch=stream:1 dispatch_time=78.31 release_t0=0.00 jobs=4 MA-50 mk: 165.24, mk/job: 18.750, mk/proc: 1.154, eps=0.479, last_mk=75.00
# [EP 148] batch=stream:1 dispatch_time=183.14 release_t0=0.00 jobs=16 MA-50 mk: 163.82, mk/job: 11.500, mk/proc: 0.836, eps=0.476, last_mk=184.00
# [EP 149] batch=stream:1 dispatch_time=37.57 release_t0=0.00 jobs=18 MA-50 mk: 163.36, mk/job: 11.778, mk/proc: 0.719, eps=0.474, last_mk=212.00
# [EP 150] batch=stream:1 dispatch_time=5.17 release_t0=0.00 jobs=10 MA-50 mk: 162.52, mk/job: 14.100, mk/proc: 0.855, eps=0.471, last_mk=141.00
# [EP 151] batch=stream:1 dispatch_time=34.46 release_t0=0.00 jobs=16 MA-50 mk: 163.92, mk/job: 13.188, mk/proc: 0.879, eps=0.469, last_mk=211.00
# [EP 152] batch=stream:1 dispatch_time=37.15 release_t0=0.00 jobs=14 MA-50 mk: 166.86, mk/job: 12.714, mk/proc: 0.913, eps=0.467, last_mk=178.00
# [EP 153] batch=stream:1 dispatch_time=93.71 release_t0=0.00 jobs=16 MA-50 mk: 165.66, mk/job: 12.375, mk/proc: 0.792, eps=0.464, last_mk=198.00
# [EP 154] batch=stream:1 dispatch_time=381.64 release_t0=0.00 jobs=17 MA-50 mk: 168.54, mk/job: 12.176, mk/proc: 0.863, eps=0.462, last_mk=207.00
# [EP 155] batch=stream:1 dispatch_time=23.70 release_t0=0.00 jobs=21 MA-50 mk: 169.22, mk/job: 12.381, mk/proc: 0.765, eps=0.460, last_mk=260.00
# [EP 156] batch=stream:1 dispatch_time=5.28 release_t0=0.00 jobs=1 MA-50 mk: 166.16, mk/job: 33.000, mk/proc: 2.200, eps=0.458, last_mk=33.00
# [EP 157] batch=stream:1 dispatch_time=24.95 release_t0=0.00 jobs=17 MA-50 mk: 167.74, mk/job: 12.412, mk/proc: 0.812, eps=0.455, last_mk=211.00
# [EP 158] batch=stream:1 dispatch_time=10.26 release_t0=0.00 jobs=13 MA-50 mk: 169.06, mk/job: 12.923, mk/proc: 0.840, eps=0.453, last_mk=168.00
# [EP 159] batch=stream:1 dispatch_time=2.70 release_t0=0.00 jobs=15 MA-50 mk: 169.52, mk/job: 11.200, mk/proc: 0.764, eps=0.451, last_mk=168.00
# [EP 160] batch=stream:1 dispatch_time=250.94 release_t0=0.00 jobs=15 MA-50 mk: 167.30, mk/job: 12.667, mk/proc: 0.760, eps=0.448, last_mk=190.00
# [EP 161] batch=stream:1 dispatch_time=2.82 release_t0=0.00 jobs=7 MA-50 mk: 164.34, mk/job: 14.286, mk/proc: 0.909, eps=0.446, last_mk=100.00
# [EP 162] batch=stream:1 dispatch_time=108.75 release_t0=0.00 jobs=25 MA-50 mk: 166.86, mk/job: 12.280, mk/proc: 0.808, eps=0.444, last_mk=307.00
# [EP 163] batch=stream:1 dispatch_time=53.18 release_t0=0.00 jobs=18 MA-50 mk: 168.28, mk/job: 12.611, mk/proc: 0.825, eps=0.442, last_mk=227.00
# [EP 164] batch=stream:1 dispatch_time=144.66 release_t0=0.00 jobs=21 MA-50 mk: 169.66, mk/job: 13.381, mk/proc: 0.814, eps=0.440, last_mk=281.00
# [EP 165] batch=stream:1 dispatch_time=85.74 release_t0=0.00 jobs=17 MA-50 mk: 173.24, mk/job: 12.765, mk/proc: 0.964, eps=0.437, last_mk=217.00
# [EP 166] batch=stream:1 dispatch_time=71.68 release_t0=0.00 jobs=9 MA-50 mk: 170.76, mk/job: 14.000, mk/proc: 1.096, eps=0.435, last_mk=126.00
# [EP 167] batch=stream:1 dispatch_time=131.11 release_t0=0.00 jobs=5 MA-50 mk: 168.40, mk/job: 15.600, mk/proc: 0.918, eps=0.433, last_mk=78.00
# [EP 168] batch=stream:1 dispatch_time=65.90 release_t0=0.00 jobs=5 MA-50 mk: 167.62, mk/job: 16.000, mk/proc: 0.889, eps=0.431, last_mk=80.00
# [EP 169] batch=stream:1 dispatch_time=83.23 release_t0=0.00 jobs=24 MA-50 mk: 167.42, mk/job: 12.167, mk/proc: 0.811, eps=0.429, last_mk=292.00
# [EP 170] batch=stream:1 dispatch_time=54.91 release_t0=0.00 jobs=8 MA-50 mk: 168.90, mk/job: 14.500, mk/proc: 0.967, eps=0.427, last_mk=116.00
# [EP 171] batch=stream:1 dispatch_time=155.23 release_t0=0.00 jobs=21 MA-50 mk: 172.72, mk/job: 12.048, mk/proc: 0.830, eps=0.424, last_mk=253.00
# [EP 172] batch=stream:1 dispatch_time=74.17 release_t0=0.00 jobs=10 MA-50 mk: 170.64, mk/job: 14.800, mk/proc: 0.897, eps=0.422, last_mk=148.00
# [EP 173] batch=stream:1 dispatch_time=125.65 release_t0=0.00 jobs=23 MA-50 mk: 172.88, mk/job: 11.565, mk/proc: 0.782, eps=0.420, last_mk=266.00
# [EP 174] batch=stream:1 dispatch_time=74.73 release_t0=0.00 jobs=10 MA-50 mk: 170.84, mk/job: 14.300, mk/proc: 0.953, eps=0.418, last_mk=143.00
# [EP 175] batch=stream:1 dispatch_time=76.27 release_t0=0.00 jobs=17 MA-50 mk: 170.08, mk/job: 11.765, mk/proc: 0.784, eps=0.416, last_mk=200.00
# [EP 176] batch=stream:1 dispatch_time=85.02 release_t0=0.00 jobs=19 MA-50 mk: 169.44, mk/job: 12.632, mk/proc: 0.800, eps=0.414, last_mk=240.00
# [EP 177] batch=stream:1 dispatch_time=15.08 release_t0=0.00 jobs=25 MA-50 mk: 171.82, mk/job: 10.000, mk/proc: 0.714, eps=0.412, last_mk=250.00
# [EP 178] batch=stream:1 dispatch_time=44.29 release_t0=0.00 jobs=18 MA-50 mk: 172.50, mk/job: 10.944, mk/proc: 0.730, eps=0.410, last_mk=197.00
# [EP 179] batch=stream:1 dispatch_time=83.24 release_t0=0.00 jobs=7 MA-50 mk: 168.36, mk/job: 12.429, mk/proc: 0.870, eps=0.408, last_mk=87.00
# [EP 180] batch=stream:1 dispatch_time=24.38 release_t0=0.00 jobs=25 MA-50 mk: 173.44, mk/job: 11.760, mk/proc: 0.828, eps=0.406, last_mk=294.00
# [EP 181] batch=stream:1 dispatch_time=1.35 release_t0=0.00 jobs=6 MA-50 mk: 170.64, mk/job: 13.833, mk/proc: 1.038, eps=0.404, last_mk=83.00
# [EP 182] batch=stream:1 dispatch_time=146.11 release_t0=0.00 jobs=25 MA-50 mk: 173.76, mk/job: 12.320, mk/proc: 0.821, eps=0.402, last_mk=308.00
# [EP 183] batch=stream:1 dispatch_time=169.88 release_t0=0.00 jobs=1 MA-50 mk: 172.84, mk/job: 33.000, mk/proc: 2.200, eps=0.400, last_mk=33.00
# [EP 184] batch=stream:1 dispatch_time=16.10 release_t0=0.00 jobs=4 MA-50 mk: 169.04, mk/job: 17.500, mk/proc: 1.167, eps=0.398, last_mk=70.00
# [EP 185] batch=stream:1 dispatch_time=37.15 release_t0=0.00 jobs=14 MA-50 mk: 166.76, mk/job: 12.214, mk/proc: 0.877, eps=0.396, last_mk=171.00
# [EP 186] batch=stream:1 dispatch_time=29.28 release_t0=0.00 jobs=20 MA-50 mk: 169.04, mk/job: 10.150, mk/proc: 0.725, eps=0.394, last_mk=203.00
# [EP 187] batch=stream:1 dispatch_time=49.93 release_t0=0.00 jobs=25 MA-50 mk: 172.56, mk/job: 12.400, mk/proc: 0.765, eps=0.392, last_mk=310.00
# [EP 188] batch=stream:1 dispatch_time=3.59 release_t0=0.00 jobs=23 MA-50 mk: 177.72, mk/job: 12.870, mk/proc: 0.811, eps=0.390, last_mk=296.00
# [EP 189] batch=stream:1 dispatch_time=61.99 release_t0=0.00 jobs=1 MA-50 mk: 177.70, mk/job: 33.000, mk/proc: 2.200, eps=0.388, last_mk=33.00
# [EP 190] batch=stream:1 dispatch_time=15.17 release_t0=0.00 jobs=14 MA-50 mk: 177.30, mk/job: 13.000, mk/proc: 0.910, eps=0.386, last_mk=182.00
# [EP 191] batch=stream:1 dispatch_time=94.97 release_t0=0.00 jobs=22 MA-50 mk: 178.48, mk/job: 11.318, mk/proc: 0.732, eps=0.384, last_mk=249.00
# [EP 192] batch=stream:1 dispatch_time=16.56 release_t0=0.00 jobs=4 MA-50 mk: 175.64, mk/job: 14.000, mk/proc: 1.120, eps=0.382, last_mk=56.00
# [EP 193] batch=stream:1 dispatch_time=42.29 release_t0=0.00 jobs=5 MA-50 mk: 175.72, mk/job: 14.600, mk/proc: 0.973, eps=0.380, last_mk=73.00
# [EP 194] batch=stream:1 dispatch_time=77.63 release_t0=0.00 jobs=5 MA-50 mk: 176.48, mk/job: 15.400, mk/proc: 1.027, eps=0.378, last_mk=77.00
# [EP 195] batch=stream:1 dispatch_time=181.20 release_t0=0.00 jobs=16 MA-50 mk: 174.50, mk/job: 11.438, mk/proc: 0.813, eps=0.376, last_mk=183.00
# [EP 196] batch=stream:1 dispatch_time=353.12 release_t0=0.00 jobs=14 MA-50 mk: 176.80, mk/job: 12.500, mk/proc: 0.946, eps=0.374, last_mk=175.00
# [EP 197] batch=stream:1 dispatch_time=96.66 release_t0=0.00 jobs=4 MA-50 mk: 176.68, mk/job: 17.250, mk/proc: 1.150, eps=0.373, last_mk=69.00
# [EP 198] batch=stream:1 dispatch_time=17.34 release_t0=0.00 jobs=20 MA-50 mk: 178.06, mk/job: 12.650, mk/proc: 0.816, eps=0.371, last_mk=253.00
# [EP 199] batch=stream:1 dispatch_time=7.39 release_t0=0.00 jobs=17 MA-50 mk: 177.86, mk/job: 11.882, mk/proc: 0.808, eps=0.369, last_mk=202.00
# [EP 200] batch=stream:1 dispatch_time=12.86 release_t0=0.00 jobs=13 MA-50 mk: 178.30, mk/job: 12.538, mk/proc: 0.758, eps=0.367, last_mk=163.00
# [EP 201] batch=stream:1 dispatch_time=169.88 release_t0=0.00 jobs=1 MA-50 mk: 174.74, mk/job: 33.000, mk/proc: 2.200, eps=0.365, last_mk=33.00
# [EP 202] batch=stream:1 dispatch_time=29.29 release_t0=0.00 jobs=11 MA-50 mk: 174.30, mk/job: 14.182, mk/proc: 0.918, eps=0.363, last_mk=156.00
# [EP 203] batch=stream:1 dispatch_time=57.16 release_t0=0.00 jobs=23 MA-50 mk: 175.80, mk/job: 11.870, mk/proc: 0.803, eps=0.361, last_mk=273.00
# [EP 204] batch=stream:1 dispatch_time=12.16 release_t0=0.00 jobs=2 MA-50 mk: 172.52, mk/job: 21.500, mk/proc: 1.720, eps=0.360, last_mk=43.00
# [EP 205] batch=stream:1 dispatch_time=81.10 release_t0=0.00 jobs=15 MA-50 mk: 171.04, mk/job: 12.400, mk/proc: 0.930, eps=0.358, last_mk=186.00
# [EP 206] batch=stream:1 dispatch_time=178.56 release_t0=0.00 jobs=8 MA-50 mk: 172.32, mk/job: 12.125, mk/proc: 0.776, eps=0.356, last_mk=97.00
# [EP 207] batch=stream:1 dispatch_time=51.80 release_t0=0.00 jobs=6 MA-50 mk: 170.10, mk/job: 16.667, mk/proc: 1.053, eps=0.354, last_mk=100.00
# [EP 208] batch=stream:1 dispatch_time=148.70 release_t0=0.00 jobs=3 MA-50 mk: 167.70, mk/job: 16.000, mk/proc: 1.067, eps=0.353, last_mk=48.00
# [EP 209] batch=stream:1 dispatch_time=279.86 release_t0=0.00 jobs=12 MA-50 mk: 167.04, mk/job: 11.250, mk/proc: 0.750, eps=0.351, last_mk=135.00
# [EP 210] batch=stream:1 dispatch_time=164.57 release_t0=0.00 jobs=12 MA-50 mk: 166.44, mk/job: 13.333, mk/proc: 0.762, eps=0.349, last_mk=160.00
# [EP 211] batch=stream:1 dispatch_time=3.51 release_t0=0.00 jobs=17 MA-50 mk: 168.00, mk/job: 10.471, mk/proc: 0.757, eps=0.347, last_mk=178.00
# [EP 212] batch=stream:1 dispatch_time=146.45 release_t0=0.00 jobs=5 MA-50 mk: 163.76, mk/job: 19.000, mk/proc: 1.188, eps=0.346, last_mk=95.00
# [EP 213] batch=stream:1 dispatch_time=36.90 release_t0=0.00 jobs=21 MA-50 mk: 164.10, mk/job: 11.619, mk/proc: 0.751, eps=0.344, last_mk=244.00
# [EP 214] batch=stream:1 dispatch_time=8.32 release_t0=0.00 jobs=19 MA-50 mk: 162.62, mk/job: 10.895, mk/proc: 0.702, eps=0.342, last_mk=207.00
# [EP 215] batch=stream:1 dispatch_time=252.43 release_t0=0.00 jobs=13 MA-50 mk: 161.68, mk/job: 13.077, mk/proc: 0.756, eps=0.340, last_mk=170.00
# [EP 216] batch=stream:1 dispatch_time=35.32 release_t0=0.00 jobs=3 MA-50 mk: 159.82, mk/job: 11.000, mk/proc: 0.943, eps=0.339, last_mk=33.00
# [EP 217] batch=stream:1 dispatch_time=85.52 release_t0=0.00 jobs=2 MA-50 mk: 158.86, mk/job: 15.000, mk/proc: 1.200, eps=0.337, last_mk=30.00
# [EP 218] batch=stream:1 dispatch_time=79.27 release_t0=0.00 jobs=16 MA-50 mk: 160.68, mk/job: 10.688, mk/proc: 0.760, eps=0.335, last_mk=171.00
# [EP 219] batch=stream:1 dispatch_time=264.62 release_t0=0.00 jobs=24 MA-50 mk: 159.96, mk/job: 10.667, mk/proc: 0.701, eps=0.334, last_mk=256.00
# [EP 220] batch=stream:1 dispatch_time=220.74 release_t0=0.00 jobs=18 MA-50 mk: 162.22, mk/job: 12.722, mk/proc: 0.790, eps=0.332, last_mk=229.00
# [EP 221] batch=stream:1 dispatch_time=223.86 release_t0=0.00 jobs=4 MA-50 mk: 158.64, mk/job: 18.500, mk/proc: 1.138, eps=0.330, last_mk=74.00
# [EP 222] batch=stream:1 dispatch_time=172.87 release_t0=0.00 jobs=16 MA-50 mk: 159.22, mk/job: 11.062, mk/proc: 0.770, eps=0.329, last_mk=177.00
# [EP 223] batch=stream:1 dispatch_time=159.99 release_t0=0.00 jobs=1 MA-50 mk: 154.52, mk/job: 31.000, mk/proc: 2.067, eps=0.327, last_mk=31.00
# [EP 224] batch=stream:1 dispatch_time=81.59 release_t0=0.00 jobs=21 MA-50 mk: 156.46, mk/job: 11.429, mk/proc: 0.800, eps=0.325, last_mk=240.00
# [EP 225] batch=stream:1 dispatch_time=5.44 release_t0=0.00 jobs=23 MA-50 mk: 157.98, mk/job: 12.000, mk/proc: 0.800, eps=0.324, last_mk=276.00
# [EP 226] batch=stream:1 dispatch_time=41.03 release_t0=0.00 jobs=18 MA-50 mk: 157.68, mk/job: 12.500, mk/proc: 0.789, eps=0.322, last_mk=225.00
# [EP 227] batch=stream:1 dispatch_time=68.78 release_t0=0.00 jobs=12 MA-50 mk: 156.48, mk/job: 15.833, mk/proc: 0.974, eps=0.321, last_mk=190.00
# [EP 228] batch=stream:1 dispatch_time=97.78 release_t0=0.00 jobs=15 MA-50 mk: 156.16, mk/job: 12.067, mk/proc: 0.804, eps=0.319, last_mk=181.00
# [EP 229] batch=stream:1 dispatch_time=11.99 release_t0=0.00 jobs=9 MA-50 mk: 156.68, mk/job: 12.556, mk/proc: 1.027, eps=0.317, last_mk=113.00
# [EP 230] batch=stream:1 dispatch_time=66.08 release_t0=0.00 jobs=8 MA-50 mk: 152.94, mk/job: 13.375, mk/proc: 0.892, eps=0.316, last_mk=107.00
# [EP 231] batch=stream:1 dispatch_time=248.76 release_t0=0.00 jobs=22 MA-50 mk: 156.64, mk/job: 12.182, mk/proc: 0.777, eps=0.314, last_mk=268.00
# [EP 232] batch=stream:1 dispatch_time=56.81 release_t0=0.00 jobs=1 MA-50 mk: 151.04, mk/job: 28.000, mk/proc: 2.800, eps=0.313, last_mk=28.00
# [EP 233] batch=stream:1 dispatch_time=31.74 release_t0=0.00 jobs=10 MA-50 mk: 152.92, mk/job: 12.700, mk/proc: 0.770, eps=0.311, last_mk=127.00
# [EP 234] batch=stream:1 dispatch_time=51.30 release_t0=0.00 jobs=11 MA-50 mk: 154.16, mk/job: 12.000, mk/proc: 0.852, eps=0.309, last_mk=132.00
# [EP 235] batch=stream:1 dispatch_time=86.97 release_t0=0.00 jobs=4 MA-50 mk: 152.00, mk/job: 15.750, mk/proc: 1.260, eps=0.308, last_mk=63.00
# [EP 236] batch=stream:1 dispatch_time=124.02 release_t0=0.00 jobs=16 MA-50 mk: 151.76, mk/job: 11.938, mk/proc: 0.780, eps=0.306, last_mk=191.00
# [EP 237] batch=stream:1 dispatch_time=402.14 release_t0=0.00 jobs=3 MA-50 mk: 146.58, mk/job: 17.000, mk/proc: 0.927, eps=0.305, last_mk=51.00
# [EP 238] batch=stream:1 dispatch_time=165.87 release_t0=0.00 jobs=13 MA-50 mk: 144.22, mk/job: 13.692, mk/proc: 0.937, eps=0.303, last_mk=178.00
# [EP 239] batch=stream:1 dispatch_time=97.33 release_t0=0.00 jobs=1 MA-50 mk: 144.22, mk/job: 33.000, mk/proc: 2.200, eps=0.302, last_mk=33.00
# [EP 240] batch=stream:1 dispatch_time=53.77 release_t0=0.00 jobs=24 MA-50 mk: 145.76, mk/job: 10.792, mk/proc: 0.740, eps=0.300, last_mk=259.00
# [EP 241] batch=stream:1 dispatch_time=233.56 release_t0=0.00 jobs=11 MA-50 mk: 144.00, mk/job: 14.636, mk/proc: 0.805, eps=0.299, last_mk=161.00
# [EP 242] batch=stream:1 dispatch_time=431.21 release_t0=0.00 jobs=12 MA-50 mk: 145.90, mk/job: 12.583, mk/proc: 0.795, eps=0.297, last_mk=151.00
# [EP 243] batch=stream:1 dispatch_time=127.23 release_t0=0.00 jobs=1 MA-50 mk: 145.12, mk/job: 34.000, mk/proc: 1.700, eps=0.296, last_mk=34.00
# [EP 244] batch=stream:1 dispatch_time=223.71 release_t0=0.00 jobs=4 MA-50 mk: 144.70, mk/job: 14.000, mk/proc: 1.400, eps=0.294, last_mk=56.00
# [EP 245] batch=stream:1 dispatch_time=6.63 release_t0=0.00 jobs=13 MA-50 mk: 144.24, mk/job: 12.308, mk/proc: 0.780, eps=0.293, last_mk=160.00
# [EP 246] batch=stream:1 dispatch_time=73.02 release_t0=0.00 jobs=18 MA-50 mk: 145.12, mk/job: 12.167, mk/proc: 0.755, eps=0.291, last_mk=219.00
# [EP 247] batch=stream:1 dispatch_time=21.67 release_t0=0.00 jobs=23 MA-50 mk: 149.40, mk/job: 12.304, mk/proc: 0.755, eps=0.290, last_mk=283.00
# [EP 248] batch=stream:1 dispatch_time=13.12 release_t0=0.00 jobs=13 MA-50 mk: 147.38, mk/job: 11.692, mk/proc: 0.822, eps=0.288, last_mk=152.00
# [EP 249] batch=stream:1 dispatch_time=8.32 release_t0=0.00 jobs=13 MA-50 mk: 146.40, mk/job: 11.769, mk/proc: 0.827, eps=0.287, last_mk=153.00
# [EP 250] batch=stream:1 dispatch_time=56.18 release_t0=0.00 jobs=17 MA-50 mk: 147.12, mk/job: 11.706, mk/proc: 0.751, eps=0.286, last_mk=199.00
# [EP 251] batch=stream:1 dispatch_time=58.99 release_t0=0.00 jobs=9 MA-50 mk: 148.84, mk/job: 13.222, mk/proc: 0.992, eps=0.284, last_mk=119.00
# [EP 252] batch=stream:1 dispatch_time=49.03 release_t0=0.00 jobs=6 MA-50 mk: 147.60, mk/job: 15.667, mk/proc: 0.940, eps=0.283, last_mk=94.00
# [EP 253] batch=stream:1 dispatch_time=24.01 release_t0=0.00 jobs=7 MA-50 mk: 144.28, mk/job: 15.286, mk/proc: 0.892, eps=0.281, last_mk=107.00
# [EP 254] batch=stream:1 dispatch_time=116.25 release_t0=0.00 jobs=13 MA-50 mk: 146.78, mk/job: 12.923, mk/proc: 0.800, eps=0.280, last_mk=168.00
# [EP 255] batch=stream:1 dispatch_time=167.60 release_t0=0.00 jobs=2 MA-50 mk: 144.08, mk/job: 25.500, mk/proc: 1.457, eps=0.279, last_mk=51.00
# [EP 256] batch=stream:1 dispatch_time=129.76 release_t0=0.00 jobs=21 MA-50 mk: 146.74, mk/job: 10.952, mk/proc: 0.754, eps=0.277, last_mk=230.00
# [EP 257] batch=stream:1 dispatch_time=131.89 release_t0=0.00 jobs=22 MA-50 mk: 149.50, mk/job: 10.818, mk/proc: 0.768, eps=0.276, last_mk=238.00
# [EP 258] batch=stream:1 dispatch_time=164.34 release_t0=0.00 jobs=24 MA-50 mk: 154.06, mk/job: 11.500, mk/proc: 0.756, eps=0.274, last_mk=276.00
# [EP 259] batch=stream:1 dispatch_time=16.79 release_t0=0.00 jobs=25 MA-50 mk: 156.74, mk/job: 10.760, mk/proc: 0.699, eps=0.273, last_mk=269.00
# [EP 260] batch=stream:1 dispatch_time=92.74 release_t0=0.00 jobs=23 MA-50 mk: 159.14, mk/job: 12.174, mk/proc: 0.812, eps=0.272, last_mk=280.00
# [EP 261] batch=stream:1 dispatch_time=25.28 release_t0=0.00 jobs=17 MA-50 mk: 158.96, mk/job: 9.941, mk/proc: 0.735, eps=0.270, last_mk=169.00
# [EP 262] batch=stream:1 dispatch_time=177.95 release_t0=0.00 jobs=16 MA-50 mk: 160.56, mk/job: 10.938, mk/proc: 0.761, eps=0.269, last_mk=175.00
# [EP 263] batch=stream:1 dispatch_time=125.40 release_t0=0.00 jobs=19 MA-50 mk: 160.30, mk/job: 12.158, mk/proc: 0.811, eps=0.268, last_mk=231.00
# [EP 264] batch=stream:1 dispatch_time=61.02 release_t0=0.00 jobs=7 MA-50 mk: 158.02, mk/job: 13.286, mk/proc: 0.775, eps=0.266, last_mk=93.00
# [EP 265] batch=stream:1 dispatch_time=11.78 release_t0=0.00 jobs=19 MA-50 mk: 159.22, mk/job: 12.105, mk/proc: 0.807, eps=0.265, last_mk=230.00
# [EP 266] batch=stream:1 dispatch_time=74.54 release_t0=0.00 jobs=24 MA-50 mk: 164.10, mk/job: 11.542, mk/proc: 0.769, eps=0.264, last_mk=277.00
# [EP 267] batch=stream:1 dispatch_time=9.06 release_t0=0.00 jobs=5 MA-50 mk: 164.98, mk/job: 14.800, mk/proc: 0.987, eps=0.262, last_mk=74.00
# [EP 268] batch=stream:1 dispatch_time=120.14 release_t0=0.00 jobs=1 MA-50 mk: 162.18, mk/job: 31.000, mk/proc: 2.067, eps=0.261, last_mk=31.00
# [EP 269] batch=stream:1 dispatch_time=290.15 release_t0=0.00 jobs=19 MA-50 mk: 161.16, mk/job: 10.789, mk/proc: 0.732, eps=0.260, last_mk=205.00
# [EP 270] batch=stream:1 dispatch_time=66.51 release_t0=0.00 jobs=20 MA-50 mk: 160.98, mk/job: 11.000, mk/proc: 0.746, eps=0.258, last_mk=220.00
# [EP 271] batch=stream:1 dispatch_time=59.85 release_t0=0.00 jobs=3 MA-50 mk: 160.36, mk/job: 14.333, mk/proc: 1.075, eps=0.257, last_mk=43.00
# [EP 272] batch=stream:1 dispatch_time=21.40 release_t0=0.00 jobs=19 MA-50 mk: 161.44, mk/job: 12.158, mk/proc: 0.797, eps=0.256, last_mk=231.00
# [EP 273] batch=stream:1 dispatch_time=29.51 release_t0=0.00 jobs=20 MA-50 mk: 165.90, mk/job: 12.700, mk/proc: 0.794, eps=0.255, last_mk=254.00
# [EP 274] batch=stream:1 dispatch_time=77.36 release_t0=0.00 jobs=1 MA-50 mk: 161.78, mk/job: 34.000, mk/proc: 3.400, eps=0.253, last_mk=34.00
# [EP 275] batch=stream:1 dispatch_time=284.59 release_t0=0.00 jobs=9 MA-50 mk: 158.70, mk/job: 13.556, mk/proc: 0.904, eps=0.252, last_mk=122.00
# [EP 276] batch=stream:1 dispatch_time=135.54 release_t0=0.00 jobs=13 MA-50 mk: 157.60, mk/job: 13.077, mk/proc: 0.829, eps=0.251, last_mk=170.00
# [EP 277] batch=stream:1 dispatch_time=47.61 release_t0=0.00 jobs=9 MA-50 mk: 155.60, mk/job: 10.000, mk/proc: 0.750, eps=0.249, last_mk=90.00
# [EP 278] batch=stream:1 dispatch_time=53.94 release_t0=0.00 jobs=25 MA-50 mk: 157.04, mk/job: 10.120, mk/proc: 0.666, eps=0.248, last_mk=253.00
# [EP 279] batch=stream:1 dispatch_time=230.48 release_t0=0.00 jobs=4 MA-50 mk: 156.02, mk/job: 15.500, mk/proc: 1.033, eps=0.247, last_mk=62.00
# [EP 280] batch=stream:1 dispatch_time=66.55 release_t0=0.00 jobs=21 MA-50 mk: 159.28, mk/job: 12.857, mk/proc: 0.818, eps=0.246, last_mk=270.00
# [EP 281] batch=stream:1 dispatch_time=12.47 release_t0=0.00 jobs=24 MA-50 mk: 159.12, mk/job: 10.833, mk/proc: 0.722, eps=0.245, last_mk=260.00
# [EP 282] batch=stream:1 dispatch_time=64.26 release_t0=0.00 jobs=23 MA-50 mk: 163.80, mk/job: 11.391, mk/proc: 0.771, eps=0.243, last_mk=262.00
# [EP 283] batch=stream:1 dispatch_time=45.56 release_t0=0.00 jobs=20 MA-50 mk: 165.46, mk/job: 10.500, mk/proc: 0.700, eps=0.242, last_mk=210.00
# [EP 284] batch=stream:1 dispatch_time=36.77 release_t0=0.00 jobs=9 MA-50 mk: 164.66, mk/job: 10.222, mk/proc: 0.800, eps=0.241, last_mk=92.00
# [EP 285] batch=stream:1 dispatch_time=220.33 release_t0=0.00 jobs=4 MA-50 mk: 164.76, mk/job: 17.000, mk/proc: 1.046, eps=0.240, last_mk=68.00
# [EP 286] batch=stream:1 dispatch_time=141.80 release_t0=0.00 jobs=14 MA-50 mk: 164.10, mk/job: 11.286, mk/proc: 0.735, eps=0.238, last_mk=158.00
# [EP 287] batch=stream:1 dispatch_time=16.59 release_t0=0.00 jobs=3 MA-50 mk: 163.86, mk/job: 13.000, mk/proc: 0.780, eps=0.237, last_mk=39.00
# [EP 288] batch=stream:1 dispatch_time=109.31 release_t0=0.00 jobs=15 MA-50 mk: 163.88, mk/job: 11.933, mk/proc: 0.702, eps=0.236, last_mk=179.00
# [EP 289] batch=stream:1 dispatch_time=122.61 release_t0=0.00 jobs=23 MA-50 mk: 168.32, mk/job: 11.087, mk/proc: 0.729, eps=0.235, last_mk=255.00
# [EP 290] batch=stream:1 dispatch_time=2.66 release_t0=0.00 jobs=6 MA-50 mk: 164.88, mk/job: 14.500, mk/proc: 0.916, eps=0.234, last_mk=87.00
# [EP 291] batch=stream:1 dispatch_time=18.20 release_t0=0.00 jobs=17 MA-50 mk: 165.50, mk/job: 11.294, mk/proc: 0.738, eps=0.233, last_mk=192.00
# [EP 292] batch=stream:1 dispatch_time=124.28 release_t0=0.00 jobs=6 MA-50 mk: 164.22, mk/job: 14.500, mk/proc: 0.916, eps=0.231, last_mk=87.00
# [EP 293] batch=stream:1 dispatch_time=35.93 release_t0=0.00 jobs=17 MA-50 mk: 167.64, mk/job: 12.059, mk/proc: 0.759, eps=0.230, last_mk=205.00
# [EP 294] batch=stream:1 dispatch_time=1.66 release_t0=0.00 jobs=5 MA-50 mk: 167.92, mk/job: 14.000, mk/proc: 0.824, eps=0.229, last_mk=70.00
# [EP 295] batch=stream:1 dispatch_time=159.32 release_t0=0.00 jobs=16 MA-50 mk: 167.60, mk/job: 9.000, mk/proc: 0.640, eps=0.228, last_mk=144.00
# [EP 296] batch=stream:1 dispatch_time=52.84 release_t0=0.00 jobs=2 MA-50 mk: 163.82, mk/job: 15.000, mk/proc: 1.200, eps=0.227, last_mk=30.00
# [EP 297] batch=stream:1 dispatch_time=76.98 release_t0=0.00 jobs=16 MA-50 mk: 161.66, mk/job: 10.938, mk/proc: 0.833, eps=0.226, last_mk=175.00
# [EP 298] batch=stream:1 dispatch_time=91.52 release_t0=0.00 jobs=22 MA-50 mk: 163.24, mk/job: 10.500, mk/proc: 0.670, eps=0.225, last_mk=231.00
# [EP 299] batch=stream:1 dispatch_time=151.52 release_t0=0.00 jobs=1 MA-50 mk: 160.80, mk/job: 31.000, mk/proc: 2.067, eps=0.223, last_mk=31.00
# [EP 300] batch=stream:1 dispatch_time=52.07 release_t0=0.00 jobs=3 MA-50 mk: 157.58, mk/job: 12.667, mk/proc: 1.086, eps=0.222, last_mk=38.00
# [EP 301] batch=stream:1 dispatch_time=257.19 release_t0=0.00 jobs=1 MA-50 mk: 155.88, mk/job: 34.000, mk/proc: 1.700, eps=0.221, last_mk=34.00
# [EP 302] batch=stream:1 dispatch_time=110.60 release_t0=0.00 jobs=9 MA-50 mk: 155.98, mk/job: 11.000, mk/proc: 0.707, eps=0.220, last_mk=99.00
# [EP 303] batch=stream:1 dispatch_time=4.52 release_t0=0.00 jobs=5 MA-50 mk: 155.26, mk/job: 14.200, mk/proc: 1.014, eps=0.219, last_mk=71.00
# [EP 304] batch=stream:1 dispatch_time=127.75 release_t0=0.00 jobs=19 MA-50 mk: 156.10, mk/job: 11.053, mk/proc: 0.724, eps=0.218, last_mk=210.00
# [EP 305] batch=stream:1 dispatch_time=104.38 release_t0=0.00 jobs=12 MA-50 mk: 158.26, mk/job: 13.250, mk/proc: 0.837, eps=0.217, last_mk=159.00
# [EP 306] batch=stream:1 dispatch_time=70.94 release_t0=0.00 jobs=11 MA-50 mk: 156.50, mk/job: 12.909, mk/proc: 0.811, eps=0.216, last_mk=142.00
# [EP 307] batch=stream:1 dispatch_time=7.66 release_t0=0.00 jobs=7 MA-50 mk: 154.26, mk/job: 18.000, mk/proc: 1.260, eps=0.215, last_mk=126.00
# [EP 308] batch=stream:1 dispatch_time=18.68 release_t0=0.00 jobs=3 MA-50 mk: 149.54, mk/job: 13.333, mk/proc: 1.143, eps=0.214, last_mk=40.00
# [EP 309] batch=stream:1 dispatch_time=18.20 release_t0=0.00 jobs=17 MA-50 mk: 147.58, mk/job: 10.059, mk/proc: 0.658, eps=0.212, last_mk=171.00
# [EP 310] batch=stream:1 dispatch_time=28.07 release_t0=0.00 jobs=15 MA-50 mk: 145.66, mk/job: 12.267, mk/proc: 0.836, eps=0.211, last_mk=184.00
# [EP 311] batch=stream:1 dispatch_time=130.45 release_t0=0.00 jobs=4 MA-50 mk: 143.44, mk/job: 14.500, mk/proc: 1.160, eps=0.210, last_mk=58.00
# [EP 312] batch=stream:1 dispatch_time=43.64 release_t0=0.00 jobs=6 MA-50 mk: 141.52, mk/job: 13.167, mk/proc: 0.878, eps=0.209, last_mk=79.00
# [EP 313] batch=stream:1 dispatch_time=256.37 release_t0=0.00 jobs=11 MA-50 mk: 139.90, mk/job: 13.636, mk/proc: 0.833, eps=0.208, last_mk=150.00
# [EP 314] batch=stream:1 dispatch_time=9.64 release_t0=0.00 jobs=19 MA-50 mk: 141.72, mk/job: 9.684, mk/proc: 0.646, eps=0.207, last_mk=184.00
# [EP 315] batch=stream:1 dispatch_time=49.09 release_t0=0.00 jobs=20 MA-50 mk: 141.16, mk/job: 10.100, mk/proc: 0.721, eps=0.206, last_mk=202.00
# [EP 316] batch=stream:1 dispatch_time=36.96 release_t0=0.00 jobs=18 MA-50 mk: 139.50, mk/job: 10.778, mk/proc: 0.732, eps=0.205, last_mk=194.00
# [EP 317] batch=stream:1 dispatch_time=40.55 release_t0=0.00 jobs=6 MA-50 mk: 140.06, mk/job: 17.000, mk/proc: 1.020, eps=0.204, last_mk=102.00
# [EP 318] batch=stream:1 dispatch_time=4.79 release_t0=0.00 jobs=23 MA-50 mk: 144.54, mk/job: 11.087, mk/proc: 0.761, eps=0.203, last_mk=255.00
# [EP 319] batch=stream:1 dispatch_time=257.19 release_t0=0.00 jobs=1 MA-50 mk: 141.12, mk/job: 34.000, mk/proc: 1.700, eps=0.202, last_mk=34.00
# [EP 320] batch=stream:1 dispatch_time=243.66 release_t0=0.00 jobs=19 MA-50 mk: 141.18, mk/job: 11.737, mk/proc: 0.796, eps=0.201, last_mk=223.00
# [EP 321] batch=stream:1 dispatch_time=59.60 release_t0=0.00 jobs=21 MA-50 mk: 144.66, mk/job: 10.333, mk/proc: 0.638, eps=0.200, last_mk=217.00
# [EP 322] batch=stream:1 dispatch_time=237.35 release_t0=0.00 jobs=16 MA-50 mk: 143.56, mk/job: 11.000, mk/proc: 0.664, eps=0.199, last_mk=176.00
# [EP 323] batch=stream:1 dispatch_time=53.92 release_t0=0.00 jobs=25 MA-50 mk: 143.92, mk/job: 10.880, mk/proc: 0.725, eps=0.198, last_mk=272.00
# [EP 324] batch=stream:1 dispatch_time=126.82 release_t0=0.00 jobs=7 MA-50 mk: 145.28, mk/job: 14.571, mk/proc: 0.887, eps=0.197, last_mk=102.00
# [EP 325] batch=stream:1 dispatch_time=142.31 release_t0=0.00 jobs=8 MA-50 mk: 145.22, mk/job: 14.875, mk/proc: 1.035, eps=0.196, last_mk=119.00
# [EP 326] batch=stream:1 dispatch_time=33.90 release_t0=0.00 jobs=4 MA-50 mk: 142.94, mk/job: 14.000, mk/proc: 1.244, eps=0.195, last_mk=56.00
# [EP 327] batch=stream:1 dispatch_time=36.95 release_t0=0.00 jobs=1 MA-50 mk: 141.76, mk/job: 31.000, mk/proc: 2.067, eps=0.194, last_mk=31.00
# [EP 328] batch=stream:1 dispatch_time=14.21 release_t0=0.00 jobs=20 MA-50 mk: 141.00, mk/job: 10.750, mk/proc: 0.694, eps=0.193, last_mk=215.00
# [EP 329] batch=stream:1 dispatch_time=124.80 release_t0=0.00 jobs=13 MA-50 mk: 142.84, mk/job: 11.846, mk/proc: 0.790, eps=0.192, last_mk=154.00
# [EP 330] batch=stream:1 dispatch_time=120.70 release_t0=0.00 jobs=18 MA-50 mk: 141.48, mk/job: 11.222, mk/proc: 0.808, eps=0.191, last_mk=202.00
# [EP 331] batch=stream:1 dispatch_time=53.63 release_t0=0.00 jobs=10 MA-50 mk: 138.92, mk/job: 13.200, mk/proc: 0.825, eps=0.190, last_mk=132.00
# [EP 332] batch=stream:1 dispatch_time=19.43 release_t0=0.00 jobs=17 MA-50 mk: 137.68, mk/job: 11.765, mk/proc: 0.755, eps=0.189, last_mk=200.00
# [EP 333] batch=stream:1 dispatch_time=5.58 release_t0=0.00 jobs=7 MA-50 mk: 134.94, mk/job: 10.429, mk/proc: 0.695, eps=0.188, last_mk=73.00
# [EP 334] batch=stream:1 dispatch_time=197.81 release_t0=0.00 jobs=2 MA-50 mk: 133.92, mk/job: 20.500, mk/proc: 1.367, eps=0.187, last_mk=41.00
# ...
# [STREAM 1670] batches=1 jobs=12 makespan=145.00s
# [STREAM 1671] batches=1 jobs=18 makespan=180.00s
# [STREAM 1672] batches=1 jobs=16 makespan=148.00s
# [STREAM 1673] batches=1 jobs=15 makespan=160.00s
# [STREAM 1674] batches=1 jobs=3 makespan=37.00s
# [STREAM 1675] batches=1 jobs=1 makespan=34.00s
# [STREAM 1676] batches=1 jobs=4 makespan=76.00s
# [STREAM 1677] batches=1 jobs=21 makespan=202.00s
# [STREAM 1678] batches=1 jobs=13 makespan=167.00s
# [STREAM 1679] batches=1 jobs=18 makespan=171.00s
# [STREAM 1680] batches=1 jobs=19 makespan=205.00s
# [STREAM 1681] batches=1 jobs=17 makespan=180.00s
# [STREAM 1682] batches=1 jobs=20 makespan=193.00s
# [STREAM 1683] batches=1 jobs=1 makespan=36.00s
# [STREAM 1684] batches=1 jobs=5 makespan=79.00s
# [STREAM 1685] batches=1 jobs=10 makespan=107.00s
# [STREAM 1686] batches=1 jobs=4 makespan=62.00s
# [STREAM 1687] batches=1 jobs=11 makespan=106.00s
# [STREAM 1688] batches=1 jobs=11 makespan=110.00s
# [STREAM 1689] batches=1 jobs=6 makespan=116.00s
# [STREAM 1690] batches=1 jobs=7 makespan=97.00s
# [STREAM 1691] batches=1 jobs=17 makespan=181.00s
# [STREAM 1692] batches=1 jobs=16 makespan=171.00s
# [STREAM 1693] batches=1 jobs=13 makespan=150.00s
# [STREAM 1694] batches=1 jobs=8 makespan=98.00s
# [STREAM 1695] batches=1 jobs=25 makespan=263.00s
# [STREAM 1696] batches=1 jobs=24 makespan=221.00s
