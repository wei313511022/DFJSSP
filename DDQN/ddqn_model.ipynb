# %% [markdown]
# # DDQN Runner Notebook
#
# This notebook is intentionally thin: keep parameters here, then call `main.py` modules.
# Edit the config cell and run all.

# %%
# %matplotlib qt
import os
import torch
import torch.nn as nn
import torch.optim as optim

from env import TaskSchedulingEnv
from model import QNetwork
from trainer import prepare_scenarios, train_ddqn
from evaluator import run_test_and_plot, print_batch_results

# %%
# -----------------------------
# Parameters (edit this block)
# -----------------------------
CFG = {
    # Data source and generation
    'task_file': 'dispatch_batches.jsonl',
    'train_data_dir': os.path.join(os.getcwd(), 'train_data'),
    'auto_generate_data': False,
    'gen_batches': 15,
    'gen_size': None,
    'gen_min_size': 1,
    'gen_max_size': 25,
    'gen_arrival_mean': 100,
    'gen_seed': None,
    'multi_streams': True,
    'num_streams': 200,
    'base_seed': 100,
    'stream_file_template': 'dispatch_batches_{i}.jsonl',

    # Scenario sampling
    'sampling_mode': 'full',  # full | window | subset
    'window_size': 10,
    'subset_size': 10,

    # Train/test switches
    'do_train': True,
    'do_test': True,

    # Model checkpoint
    'save_model_path': 'ddqn_policy_100epoch.pt',
    'load_model_path': None,

    # DDQN and optimizer
    'state_dim': 28,
    'action_dim': 4,
    'lr': 1e-3,
    'num_episodes': 100,
    'batch_size': 128,
    'gamma': 0.99,
    'epsilon': 1.0,
    'epsilon_end': 0.05,
    'epsilon_decay': 0.995,
    'allow_proactive_replenish': True,

    # Training visualization and profiling
    'show_train_schedule': False,
    'train_schedule_every_episodes': 1,
    'train_schedule_every_steps': 1,
    'train_schedule_window': 120.0,
    'train_schedule_window_all_axes': False,
    'train_schedule_pause': 0.01,
    'train_schedule_show_labels': False,
    'train_schedule_figsize': (14, 8),
    'show_train_route_map': False,
    'train_route_map_every_episodes': 1,
    'train_route_map_every_steps': 1,
    'train_route_map_pause': 0.01,
    'train_route_map_figsize': (9, 8),
    'train_route_map_animate': False,
    'train_route_map_time_step': 0.5,
    'train_route_map_max_frames_per_update': 120,
    'train_route_map_delay_seconds': 20.0,
    'enable_profile': True,
    'profile_cuda_sync': True,

    # Test and plotting
    'test_scenario_file': 'test_scenario_one_time.jsonl',
    'show_live': False,
    'show_live_stream': False,
    'show_interactive': False,
    'show_route_map': True,
    'show_plotly': True,
    'show_test_plots': True,
    'live_pause': 0.05,
    'live_job_file': 'live_jobs.jsonl',
    'live_start_at_end': True,
    'live_poll_interval': 0.5,
    'live_idle_sleep': 0.1,
    'live_max_steps': 100,
    'live_max_sim_time': None,
    'live_init_scenario': [],
    'live_record_dir': None,
    'live_record_every': 5,
    'live_record_dpi': 140,
    'live_make_gif': False,
    'live_gif_path': 'live_schedule.gif',
    'route_play_step': 0.5,
    'route_play_interval_ms': 120,
}

# %%
# -----------------------------
# Run pipeline
# -----------------------------
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

scenario_list = prepare_scenarios(
    task_file=CFG['task_file'],
    train_data_dir=CFG['train_data_dir'],
    auto_generate_data=CFG['auto_generate_data'],
    gen_batches=CFG['gen_batches'],
    gen_size=CFG['gen_size'],
    gen_min_size=CFG['gen_min_size'],
    gen_max_size=CFG['gen_max_size'],
    gen_arrival_mean=CFG['gen_arrival_mean'],
    gen_seed=CFG['gen_seed'],
    multi_streams=CFG['multi_streams'],
    num_streams=CFG['num_streams'],
    base_seed=CFG['base_seed'],
    stream_file_template=CFG['stream_file_template'],
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
if device.type == 'cuda':
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.set_float32_matmul_precision('high')

env = TaskSchedulingEnv()
env.allow_proactive_replenish = CFG['allow_proactive_replenish']
input_dim = CFG['state_dim'] + CFG['action_dim']
policy_net = QNetwork(input_dim).to(device)
target_net = QNetwork(input_dim).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=CFG['lr'])
criterion = nn.MSELoss()

if CFG['load_model_path'] and os.path.exists(CFG['load_model_path']):
    ckpt = torch.load(CFG['load_model_path'], map_location=device)
    if isinstance(ckpt, dict) and 'model_state' in ckpt:
        policy_net.load_state_dict(ckpt['model_state'])
        if 'target_state' in ckpt:
            target_net.load_state_dict(ckpt['target_state'])
        else:
            target_net.load_state_dict(policy_net.state_dict())
        if 'optimizer_state' in ckpt:
            optimizer.load_state_dict(ckpt['optimizer_state'])
    else:
        policy_net.load_state_dict(ckpt)
        target_net.load_state_dict(policy_net.state_dict())
    print(f"Loaded model from {CFG['load_model_path']}")

if CFG['do_train']:
    _train_info = train_ddqn(
        env=env,
        policy_net=policy_net,
        target_net=target_net,
        optimizer=optimizer,
        criterion=criterion,
        scenario_list=scenario_list,
        device=device,
        num_episodes=CFG['num_episodes'],
        batch_size=CFG['batch_size'],
        gamma=CFG['gamma'],
        epsilon=CFG['epsilon'],
        epsilon_end=CFG['epsilon_end'],
        epsilon_decay=CFG['epsilon_decay'],
        sampling_mode=CFG['sampling_mode'],
        window_size=CFG['window_size'],
        subset_size=CFG['subset_size'],
        show_train_schedule=CFG['show_train_schedule'],
        train_schedule_every_episodes=CFG['train_schedule_every_episodes'],
        train_schedule_every_steps=CFG['train_schedule_every_steps'],
        train_schedule_window=CFG['train_schedule_window'],
        train_schedule_window_all_axes=CFG['train_schedule_window_all_axes'],
        train_schedule_pause=CFG['train_schedule_pause'],
        train_schedule_show_labels=CFG['train_schedule_show_labels'],
        train_schedule_figsize=CFG['train_schedule_figsize'],
        show_train_route_map=CFG['show_train_route_map'],
        train_route_map_every_episodes=CFG['train_route_map_every_episodes'],
        train_route_map_every_steps=CFG['train_route_map_every_steps'],
        train_route_map_pause=CFG['train_route_map_pause'],
        train_route_map_figsize=CFG['train_route_map_figsize'],
        train_route_map_animate=CFG['train_route_map_animate'],
        train_route_map_time_step=CFG['train_route_map_time_step'],
        train_route_map_max_frames_per_update=CFG['train_route_map_max_frames_per_update'],
        train_route_map_delay_seconds=CFG['train_route_map_delay_seconds'],
        enable_profile=CFG['enable_profile'],
        profile_cuda_sync=CFG['profile_cuda_sync'],
    )

    if CFG['save_model_path']:
        ckpt = {
            'model_state': policy_net.state_dict(),
            'target_state': target_net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'state_dim': CFG['state_dim'],
            'action_dim': CFG['action_dim'],
            'input_dim': input_dim,
        }
        torch.save(ckpt, CFG['save_model_path'])
        print(f"Saved model to {CFG['save_model_path']}")

if CFG['do_test']:
    _mk = run_test_and_plot(
        env=env,
        policy_net=policy_net,
        device=device,
        scenario_list=scenario_list,
        test_scenario_file=CFG['test_scenario_file'],
        show_live=CFG['show_live'],
        show_live_stream=CFG['show_live_stream'],
        show_interactive=CFG['show_interactive'],
        show_route_map=CFG['show_route_map'],
        show_plotly=CFG['show_plotly'],
        show_test_plots=CFG['show_test_plots'],
        live_pause=CFG['live_pause'],
        live_job_file=CFG['live_job_file'],
        live_start_at_end=CFG['live_start_at_end'],
        live_poll_interval=CFG['live_poll_interval'],
        live_idle_sleep=CFG['live_idle_sleep'],
        live_max_steps=CFG['live_max_steps'],
        live_max_sim_time=CFG['live_max_sim_time'],
        live_init_scenario=CFG['live_init_scenario'],
        live_record_dir=CFG['live_record_dir'],
        live_record_every=CFG['live_record_every'],
        live_record_dpi=CFG['live_record_dpi'],
        live_make_gif=CFG['live_make_gif'],
        live_gif_path=CFG['live_gif_path'],
        route_play_step=CFG['route_play_step'],
        route_play_interval_ms=CFG['route_play_interval_ms'],
    )
    print_batch_results(env=env, policy_net=policy_net, device=device, scenario_list=scenario_list)
# Out:
# device = cuda
# [EP 1] batch=stream:15 dispatch_time=13.45 release_t0=0.00 jobs=212 MA-50 mk: 2926.21, mk/job: 13.803, mk/proc: 0.914, eps=0.995, last_mk=2926.21
# [EP 2] batch=stream:15 dispatch_time=16.04 release_t0=0.00 jobs=193 MA-50 mk: 2677.48, mk/job: 12.584, mk/proc: 0.829, eps=0.990, last_mk=2428.74
# [EP 3] batch=stream:15 dispatch_time=49.03 release_t0=0.00 jobs=211 MA-50 mk: 2782.63, mk/job: 14.185, mk/proc: 0.961, eps=0.985, last_mk=2992.95
# [EP 4] batch=stream:15 dispatch_time=60.16 release_t0=0.00 jobs=151 MA-50 mk: 2669.11, mk/job: 15.421, mk/proc: 1.049, eps=0.980, last_mk=2328.55
# [EP 5] batch=stream:15 dispatch_time=39.17 release_t0=0.00 jobs=213 MA-50 mk: 2661.68, mk/job: 12.357, mk/proc: 0.853, eps=0.975, last_mk=2631.94
# [EP 6] batch=stream:15 dispatch_time=83.22 release_t0=0.00 jobs=168 MA-50 mk: 2552.40, mk/job: 11.940, mk/proc: 0.785, eps=0.970, last_mk=2006.00
# [EP 7] batch=stream:15 dispatch_time=43.47 release_t0=0.00 jobs=191 MA-50 mk: 2552.39, mk/job: 13.363, mk/proc: 0.870, eps=0.966, last_mk=2552.35
# [EP 8] batch=stream:15 dispatch_time=106.03 release_t0=0.00 jobs=166 MA-50 mk: 2496.26, mk/job: 12.671, mk/proc: 0.876, eps=0.961, last_mk=2103.37
# [EP 9] batch=stream:15 dispatch_time=189.33 release_t0=0.00 jobs=168 MA-50 mk: 2502.63, mk/job: 15.200, mk/proc: 1.009, eps=0.956, last_mk=2553.60
# [EP 10] batch=stream:15 dispatch_time=58.84 release_t0=0.00 jobs=201 MA-50 mk: 2490.87, mk/job: 11.866, mk/proc: 0.768, eps=0.951, last_mk=2385.00
# [EP 11] batch=stream:15 dispatch_time=15.58 release_t0=0.00 jobs=166 MA-50 mk: 2437.06, mk/job: 11.440, mk/proc: 0.808, eps=0.946, last_mk=1899.00
# [EP 12] batch=stream:15 dispatch_time=52.84 release_t0=0.00 jobs=151 MA-50 mk: 2389.64, mk/job: 12.371, mk/proc: 0.810, eps=0.942, last_mk=1868.00
# [EP 13] batch=stream:15 dispatch_time=115.28 release_t0=0.00 jobs=210 MA-50 mk: 2399.97, mk/job: 12.019, mk/proc: 0.821, eps=0.937, last_mk=2523.97
# [EP 14] batch=stream:15 dispatch_time=204.39 release_t0=0.00 jobs=240 MA-50 mk: 2440.26, mk/job: 12.350, mk/proc: 0.869, eps=0.932, last_mk=2964.00
# [EP 15] batch=stream:15 dispatch_time=322.70 release_t0=0.00 jobs=160 MA-50 mk: 2420.86, mk/job: 13.433, mk/proc: 0.868, eps=0.928, last_mk=2149.22
# [EP 16] batch=stream:15 dispatch_time=67.11 release_t0=0.00 jobs=171 MA-50 mk: 2395.31, mk/job: 11.766, mk/proc: 0.800, eps=0.923, last_mk=2012.00
# [EP 17] batch=stream:15 dispatch_time=13.99 release_t0=0.00 jobs=187 MA-50 mk: 2409.45, mk/job: 14.095, mk/proc: 0.948, eps=0.918, last_mk=2635.70
# [EP 18] batch=stream:15 dispatch_time=86.94 release_t0=0.00 jobs=209 MA-50 mk: 2420.49, mk/job: 12.480, mk/proc: 0.825, eps=0.914, last_mk=2608.27
# [EP 19] batch=stream:15 dispatch_time=7.38 release_t0=0.00 jobs=159 MA-50 mk: 2411.54, mk/job: 14.154, mk/proc: 0.981, eps=0.909, last_mk=2250.48
# [EP 20] batch=stream:15 dispatch_time=72.83 release_t0=0.00 jobs=194 MA-50 mk: 2406.72, mk/job: 11.933, mk/proc: 0.773, eps=0.905, last_mk=2315.05
# [EP 21] batch=stream:15 dispatch_time=147.66 release_t0=0.00 jobs=172 MA-50 mk: 2398.04, mk/job: 12.933, mk/proc: 0.825, eps=0.900, last_mk=2224.39
# [EP 22] batch=stream:15 dispatch_time=124.13 release_t0=0.00 jobs=218 MA-50 mk: 2419.26, mk/job: 13.142, mk/proc: 0.880, eps=0.896, last_mk=2864.88
# [EP 23] batch=stream:15 dispatch_time=7.51 release_t0=0.00 jobs=216 MA-50 mk: 2440.47, mk/job: 13.459, mk/proc: 0.881, eps=0.891, last_mk=2907.08
# [EP 24] batch=stream:15 dispatch_time=173.62 release_t0=0.00 jobs=200 MA-50 mk: 2451.09, mk/job: 13.477, mk/proc: 0.897, eps=0.887, last_mk=2695.36
# [EP 25] batch=stream:15 dispatch_time=49.03 release_t0=0.00 jobs=211 MA-50 mk: 2473.56, mk/job: 14.279, mk/proc: 0.967, eps=0.882, last_mk=3012.95
# [EP 26] batch=stream:15 dispatch_time=189.33 release_t0=0.00 jobs=168 MA-50 mk: 2476.03, mk/job: 15.105, mk/proc: 1.003, eps=0.878, last_mk=2537.60
# [EP 27] batch=stream:15 dispatch_time=273.23 release_t0=0.00 jobs=200 MA-50 mk: 2471.73, mk/job: 11.800, mk/proc: 0.801, eps=0.873, last_mk=2360.00
# [EP 28] batch=stream:15 dispatch_time=83.22 release_t0=0.00 jobs=168 MA-50 mk: 2457.27, mk/job: 12.304, mk/proc: 0.809, eps=0.869, last_mk=2067.00
# [EP 29] batch=stream:15 dispatch_time=3.34 release_t0=0.00 jobs=199 MA-50 mk: 2457.71, mk/job: 12.412, mk/proc: 0.822, eps=0.865, last_mk=2470.00
# [EP 30] batch=stream:15 dispatch_time=154.83 release_t0=0.00 jobs=216 MA-50 mk: 2460.19, mk/job: 11.722, mk/proc: 0.799, eps=0.860, last_mk=2532.00
# [EP 31] batch=stream:15 dispatch_time=4.56 release_t0=0.00 jobs=201 MA-50 mk: 2458.96, mk/job: 12.050, mk/proc: 0.827, eps=0.856, last_mk=2422.00
# [EP 32] batch=stream:15 dispatch_time=16.50 release_t0=0.00 jobs=169 MA-50 mk: 2446.15, mk/job: 12.124, mk/proc: 0.788, eps=0.852, last_mk=2049.00
# [EP 33] batch=stream:15 dispatch_time=192.76 release_t0=0.00 jobs=178 MA-50 mk: 2438.33, mk/job: 12.294, mk/proc: 0.817, eps=0.848, last_mk=2188.32
# [EP 34] batch=stream:15 dispatch_time=111.39 release_t0=0.00 jobs=154 MA-50 mk: 2420.84, mk/job: 11.971, mk/proc: 0.790, eps=0.843, last_mk=1843.58
# [EP 35] batch=stream:15 dispatch_time=0.87 release_t0=0.00 jobs=199 MA-50 mk: 2427.29, mk/job: 13.299, mk/proc: 0.893, eps=0.839, last_mk=2646.47
# [EP 36] batch=stream:15 dispatch_time=74.54 release_t0=0.00 jobs=236 MA-50 mk: 2440.71, mk/job: 12.333, mk/proc: 0.801, eps=0.835, last_mk=2910.66
# [EP 37] batch=stream:15 dispatch_time=32.99 release_t0=0.00 jobs=197 MA-50 mk: 2438.86, mk/job: 12.041, mk/proc: 0.812, eps=0.831, last_mk=2372.00
# [EP 38] batch=stream:15 dispatch_time=66.17 release_t0=0.00 jobs=179 MA-50 mk: 2431.44, mk/job: 12.050, mk/proc: 0.799, eps=0.827, last_mk=2157.00
# [EP 39] batch=stream:15 dispatch_time=56.81 release_t0=0.00 jobs=204 MA-50 mk: 2433.56, mk/job: 12.323, mk/proc: 0.816, eps=0.822, last_mk=2513.98
# [EP 40] batch=stream:15 dispatch_time=501.58 release_t0=0.00 jobs=230 MA-50 mk: 2444.50, mk/job: 12.485, mk/proc: 0.823, eps=0.818, last_mk=2871.52
# [EP 41] batch=stream:15 dispatch_time=173.62 release_t0=0.00 jobs=200 MA-50 mk: 2451.38, mk/job: 13.632, mk/proc: 0.907, eps=0.814, last_mk=2726.36
# [EP 42] batch=stream:15 dispatch_time=107.42 release_t0=0.00 jobs=184 MA-50 mk: 2444.68, mk/job: 11.793, mk/proc: 0.782, eps=0.810, last_mk=2170.00
# [EP 43] batch=stream:15 dispatch_time=4.50 release_t0=0.00 jobs=255 MA-50 mk: 2458.20, mk/job: 11.867, mk/proc: 0.789, eps=0.806, last_mk=3026.00
# [EP 44] batch=stream:15 dispatch_time=5.44 release_t0=0.00 jobs=157 MA-50 mk: 2444.69, mk/job: 11.873, mk/proc: 0.810, eps=0.802, last_mk=1864.00
# [EP 45] batch=stream:15 dispatch_time=129.06 release_t0=0.00 jobs=250 MA-50 mk: 2455.17, mk/job: 11.664, mk/proc: 0.787, eps=0.798, last_mk=2916.00
# [EP 46] batch=stream:15 dispatch_time=13.07 release_t0=0.00 jobs=164 MA-50 mk: 2445.87, mk/job: 12.363, mk/proc: 0.841, eps=0.794, last_mk=2027.48
# [EP 47] batch=stream:15 dispatch_time=155.90 release_t0=0.00 jobs=265 MA-50 mk: 2460.76, mk/job: 11.870, mk/proc: 0.794, eps=0.790, last_mk=3145.63
# [EP 48] batch=stream:15 dispatch_time=58.69 release_t0=0.00 jobs=185 MA-50 mk: 2459.89, mk/job: 13.076, mk/proc: 0.843, eps=0.786, last_mk=2419.05
# [EP 49] batch=stream:15 dispatch_time=136.87 release_t0=0.00 jobs=229 MA-50 mk: 2468.02, mk/job: 12.481, mk/proc: 0.877, eps=0.782, last_mk=2858.08
# [EP 50] batch=stream:15 dispatch_time=3.01 release_t0=0.00 jobs=199 MA-50 mk: 2464.08, mk/job: 11.412, mk/proc: 0.756, eps=0.778, last_mk=2271.00
# [EP 51] batch=stream:15 dispatch_time=10.02 release_t0=0.00 jobs=171 MA-50 mk: 2448.05, mk/job: 12.427, mk/proc: 0.806, eps=0.774, last_mk=2125.00
# [EP 52] batch=stream:15 dispatch_time=231.77 release_t0=0.00 jobs=175 MA-50 mk: 2442.08, mk/job: 12.174, mk/proc: 0.824, eps=0.771, last_mk=2130.40
# [EP 53] batch=stream:15 dispatch_time=13.07 release_t0=0.00 jobs=164 MA-50 mk: 2422.28, mk/job: 12.210, mk/proc: 0.831, eps=0.767, last_mk=2002.48
# [EP 54] batch=stream:15 dispatch_time=59.47 release_t0=0.00 jobs=181 MA-50 mk: 2419.26, mk/job: 12.033, mk/proc: 0.811, eps=0.763, last_mk=2178.00
# [EP 55] batch=stream:15 dispatch_time=210.45 release_t0=0.00 jobs=201 MA-50 mk: 2415.77, mk/job: 12.224, mk/proc: 0.796, eps=0.759, last_mk=2457.00
# [EP 56] batch=stream:15 dispatch_time=231.69 release_t0=0.00 jobs=183 MA-50 mk: 2423.94, mk/job: 13.196, mk/proc: 0.885, eps=0.755, last_mk=2414.80
# [EP 57] batch=stream:15 dispatch_time=46.97 release_t0=0.00 jobs=170 MA-50 mk: 2414.29, mk/job: 12.175, mk/proc: 0.836, eps=0.751, last_mk=2069.79
# [EP 58] batch=stream:15 dispatch_time=22.03 release_t0=0.00 jobs=218 MA-50 mk: 2421.70, mk/job: 11.349, mk/proc: 0.766, eps=0.748, last_mk=2474.00
# [EP 59] batch=stream:15 dispatch_time=66.06 release_t0=0.00 jobs=199 MA-50 mk: 2417.51, mk/job: 11.779, mk/proc: 0.797, eps=0.744, last_mk=2344.00
# [EP 60] batch=stream:15 dispatch_time=198.11 release_t0=0.00 jobs=167 MA-50 mk: 2411.19, mk/job: 12.388, mk/proc: 0.841, eps=0.740, last_mk=2068.86
# [EP 61] batch=stream:15 dispatch_time=58.84 release_t0=0.00 jobs=201 MA-50 mk: 2421.93, mk/job: 12.119, mk/proc: 0.785, eps=0.737, last_mk=2436.00
# [EP 62] batch=stream:15 dispatch_time=27.57 release_t0=0.00 jobs=206 MA-50 mk: 2437.92, mk/job: 12.949, mk/proc: 0.863, eps=0.733, last_mk=2667.48
# [EP 63] batch=stream:15 dispatch_time=86.97 release_t0=0.00 jobs=186 MA-50 mk: 2431.34, mk/job: 11.801, mk/proc: 0.788, eps=0.729, last_mk=2195.00
# [EP 64] batch=stream:15 dispatch_time=122.61 release_t0=0.00 jobs=254 MA-50 mk: 2434.32, mk/job: 12.256, mk/proc: 0.813, eps=0.726, last_mk=3113.00
# [EP 65] batch=stream:15 dispatch_time=82.51 release_t0=0.00 jobs=187 MA-50 mk: 2436.47, mk/job: 12.067, mk/proc: 0.818, eps=0.722, last_mk=2256.60
# [EP 66] batch=stream:15 dispatch_time=124.13 release_t0=0.00 jobs=218 MA-50 mk: 2453.46, mk/job: 13.128, mk/proc: 0.879, eps=0.718, last_mk=2861.88
# [EP 67] batch=stream:15 dispatch_time=51.67 release_t0=0.00 jobs=228 MA-50 mk: 2458.86, mk/job: 12.743, mk/proc: 0.846, eps=0.715, last_mk=2905.48
# [EP 68] batch=stream:15 dispatch_time=46.67 release_t0=0.00 jobs=178 MA-50 mk: 2456.66, mk/job: 14.036, mk/proc: 0.954, eps=0.711, last_mk=2498.34
# [EP 69] batch=stream:15 dispatch_time=135.53 release_t0=0.00 jobs=218 MA-50 mk: 2484.23, mk/job: 16.647, mk/proc: 1.085, eps=0.708, last_mk=3628.94
# [EP 70] batch=stream:15 dispatch_time=72.84 release_t0=0.00 jobs=182 MA-50 mk: 2481.49, mk/job: 11.967, mk/proc: 0.792, eps=0.704, last_mk=2178.00
# [EP 71] batch=stream:15 dispatch_time=13.07 release_t0=0.00 jobs=164 MA-50 mk: 2475.55, mk/job: 11.753, mk/proc: 0.800, eps=0.701, last_mk=1927.48
# [EP 72] batch=stream:15 dispatch_time=272.21 release_t0=0.00 jobs=190 MA-50 mk: 2462.71, mk/job: 11.700, mk/proc: 0.787, eps=0.697, last_mk=2223.00
# [EP 73] batch=stream:15 dispatch_time=172.24 release_t0=0.00 jobs=171 MA-50 mk: 2449.20, mk/job: 13.050, mk/proc: 0.870, eps=0.694, last_mk=2231.57
# [EP 74] batch=stream:15 dispatch_time=65.63 release_t0=0.00 jobs=188 MA-50 mk: 2441.42, mk/job: 12.267, mk/proc: 0.790, eps=0.690, last_mk=2306.17
# [EP 75] batch=stream:15 dispatch_time=198.11 release_t0=0.00 jobs=167 MA-50 mk: 2422.70, mk/job: 12.436, mk/proc: 0.844, eps=0.687, last_mk=2076.86
# [EP 76] batch=stream:15 dispatch_time=152.12 release_t0=0.00 jobs=204 MA-50 mk: 2420.36, mk/job: 11.867, mk/proc: 0.806, eps=0.683, last_mk=2420.86
# [EP 77] batch=stream:15 dispatch_time=260.79 release_t0=0.00 jobs=184 MA-50 mk: 2426.81, mk/job: 14.578, mk/proc: 0.963, eps=0.680, last_mk=2682.34
# [EP 78] batch=stream:15 dispatch_time=28.17 release_t0=0.00 jobs=170 MA-50 mk: 2430.06, mk/job: 13.115, mk/proc: 0.861, eps=0.676, last_mk=2229.50
# [EP 79] batch=stream:15 dispatch_time=13.99 release_t0=0.00 jobs=187 MA-50 mk: 2431.73, mk/job: 13.656, mk/proc: 0.919, eps=0.673, last_mk=2553.70
# [EP 80] batch=stream:15 dispatch_time=58.69 release_t0=0.00 jobs=185 MA-50 mk: 2429.63, mk/job: 13.119, mk/proc: 0.846, eps=0.670, last_mk=2427.05
# [EP 81] batch=stream:15 dispatch_time=322.70 release_t0=0.00 jobs=160 MA-50 mk: 2423.90, mk/job: 13.345, mk/proc: 0.863, eps=0.666, last_mk=2135.22
# [EP 82] batch=stream:15 dispatch_time=73.35 release_t0=0.00 jobs=180 MA-50 mk: 2428.38, mk/job: 12.628, mk/proc: 0.830, eps=0.663, last_mk=2273.11
# [EP 83] batch=stream:15 dispatch_time=52.84 release_t0=0.00 jobs=151 MA-50 mk: 2422.56, mk/job: 12.564, mk/proc: 0.823, eps=0.660, last_mk=1897.11
# [EP 84] batch=stream:15 dispatch_time=187.66 release_t0=0.00 jobs=207 MA-50 mk: 2435.29, mk/job: 11.981, mk/proc: 0.780, eps=0.656, last_mk=2480.00
# [EP 85] batch=stream:15 dispatch_time=237.35 release_t0=0.00 jobs=221 MA-50 mk: 2440.15, mk/job: 13.076, mk/proc: 0.864, eps=0.653, last_mk=2889.69
# [EP 86] batch=stream:15 dispatch_time=71.34 release_t0=0.00 jobs=171 MA-50 mk: 2422.28, mk/job: 11.795, mk/proc: 0.789, eps=0.650, last_mk=2017.00
# [EP 87] batch=stream:15 dispatch_time=42.20 release_t0=0.00 jobs=200 MA-50 mk: 2422.28, mk/job: 11.860, mk/proc: 0.797, eps=0.647, last_mk=2372.00
# [EP 88] batch=stream:15 dispatch_time=120.41 release_t0=0.00 jobs=170 MA-50 mk: 2422.53, mk/job: 12.762, mk/proc: 0.846, eps=0.643, last_mk=2169.59
# [EP 89] batch=stream:15 dispatch_time=5.44 release_t0=0.00 jobs=157 MA-50 mk: 2408.95, mk/job: 11.688, mk/proc: 0.798, eps=0.640, last_mk=1835.00
# [EP 90] batch=stream:15 dispatch_time=195.73 release_t0=0.00 jobs=232 MA-50 mk: 2406.38, mk/job: 11.823, mk/proc: 0.774, eps=0.637, last_mk=2743.00
# [EP 91] batch=stream:15 dispatch_time=85.74 release_t0=0.00 jobs=214 MA-50 mk: 2403.19, mk/job: 11.995, mk/proc: 0.792, eps=0.634, last_mk=2567.00
# [EP 92] batch=stream:15 dispatch_time=13.99 release_t0=0.00 jobs=187 MA-50 mk: 2411.45, mk/job: 13.811, mk/proc: 0.929, eps=0.631, last_mk=2582.70
# [EP 93] batch=stream:15 dispatch_time=77.26 release_t0=0.00 jobs=159 MA-50 mk: 2391.79, mk/job: 12.849, mk/proc: 0.848, eps=0.627, last_mk=2043.00
# [EP 94] batch=stream:15 dispatch_time=7.51 release_t0=0.00 jobs=216 MA-50 mk: 2412.67, mk/job: 13.463, mk/proc: 0.881, eps=0.624, last_mk=2908.08
# [EP 95] batch=stream:15 dispatch_time=86.94 release_t0=0.00 jobs=209 MA-50 mk: 2406.65, mk/job: 12.513, mk/proc: 0.828, eps=0.621, last_mk=2615.27
# [EP 96] batch=stream:15 dispatch_time=46.97 release_t0=0.00 jobs=170 MA-50 mk: 2406.18, mk/job: 11.787, mk/proc: 0.810, eps=0.618, last_mk=2003.79
# [EP 97] batch=stream:15 dispatch_time=41.83 release_t0=0.00 jobs=166 MA-50 mk: 2387.41, mk/job: 13.297, mk/proc: 0.881, eps=0.615, last_mk=2207.38
# [EP 98] batch=stream:15 dispatch_time=77.96 release_t0=0.00 jobs=166 MA-50 mk: 2376.89, mk/job: 11.404, mk/proc: 0.781, eps=0.612, last_mk=1893.00
